# %% [markdown]
# <a href="https://colab.research.google.com/github/qmcnn/PROJECT/blob/main/Hemo_Recount.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
hemo = pd.read_csv('/content/drive/MyDrive/Project/ckdresearch2023/Hemodialysis.csv', encoding='latin1')
hemo.head()
# Out:
#    PatientUID  PatientvisitUID       ENTY OrderDttm  \
# 0     1634972          1838715  InPatient   38:00.0
# 1     1681750          1838753  InPatient   16:00.0
# 2     1681750          1838753  InPatient   22:00.0
# 3     1681750          1838753  InPatient   23:00.0
# 4     1681750          1838753  InPatient   44:00.0
#
#                                             ItemName
# 0  ãªéäµà·ÕÂÁ (Hemodialysis)  - Chronic Hemodialy...
# 1  ãªéäµà·ÕÂÁ (Hemodialysis)  - Chronic Hemodialy...
# 2  ãªéäµà·ÕÂÁ (Hemodialysis)  - Chronic Hemodialy...
# 3  ãªéäµà·ÕÂÁ (Hemodialysis)  - Chronic Hemodialy...
# 4  ãªéäµà·ÕÂÁ (Hemodialysis)  - Chronic Hemodialy...

# %%
hemo.shape
# Out:
# (149987, 5)

# %%
import pandas as pd
lab = pd.read_csv('/content/drive/MyDrive/Project/ckdresearch2023/Lab.csv')
lab.shape
# Out:
# (21641523, 11)

# %%
import pandas as pd
vital = pd.read_csv('/content/drive/MyDrive/Project/ckdresearch2023/vitalsign.csv')
vital.shape
# Out:
# (9213497, 7)

# %%
import pandas as pd
diagnosis = pd.read_csv('/content/drive/MyDrive/Project/ckdresearch2023/Diagnosis.csv')
diagnosis.shape
# Out:
# (2357574, 7)

# %%
import pandas as pd
prescription = pd.read_csv('/content/drive/MyDrive/Project/ckdresearch2023/Prescription.csv')
prescription.shape
# Out:
# (9530452, 10)

# %%
import pandas as pd
visit = pd.read_csv('/content/drive/MyDrive/Project/ckdresearch2023/Visit.csv')
visit.shape
# Out:
# <ipython-input-8-8f8a8847e6cb>:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   visit = pd.read_csv('/content/drive/MyDrive/Project/ckdresearch2023/Visit.csv')
# (1340588, 11)

# %%
# Create a list from hemo['PatientUID']
patient_uid_list = hemo['PatientUID'].unique().tolist()

# %%
# Remove patient UIDs from lab['PatientUID'] that are not in the list
lab = lab[~lab['PatientUID'].isin(patient_uid_list)]
lab.shape
# Out:
# (17728574, 11)

# %%
# Remove patient UIDs from visit['PatientUID'] that are not in the list
visit = visit[~visit['PatientUID'].isin(patient_uid_list)]
visit.shape
# Out:
# (1195332, 11)

# %%
# Remove patient UIDs from visit['PatientUID'] that are not in the list
vital = vital[~vital['PatientUID'].isin(patient_uid_list)]
vital.shape
# Out:
# (8099274, 7)

# %%
# Remove patient UIDs from visit['PatientUID'] that are not in the list
diagnosis = diagnosis[~diagnosis['PatientUID'].isin(patient_uid_list)]
diagnosis.shape
# Out:
# (2081658, 7)

# %%
# Remove patient UIDs from visit['PatientUID'] that are not in the list
prescription = prescription[~prescription['PatientUID'].isin(patient_uid_list)]
prescription.shape
# Out:
# (7845039, 10)

# %% [markdown]
# > **ตัดผู้ป่วยโรคไตออกแล้วในทุกไฟล์**

# %% [markdown]
# ##🗂️Import data: vitalsign

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
vital
# Out:
#          LabNo  PatientUID  PatientVisitUID       OrderItemName  \
# 0            1       24513          2140458  Vital Signs Record
# 1            1       24513          2341133  Vital Signs Record
# 2            1       24513          2341133  Vital Signs Record
# 3            1       24513          2341133  Vital Signs Record
# 4            1       24513          2388152  Vital Signs Record
# ...        ...         ...              ...                 ...
# 9213492      1     3437526         10261871  Vital Signs Record
# 9213493      1     3437526         10261871  Vital Signs Record
# 9213494      1     3437526         10191122  Vital Signs Record
# 9213495      1     3437526         10191122  Vital Signs Record
# 9213496      1     3437526         10261871  Vital Signs Record
#
#            ResultItemName ResultValue                    CWhen
# 0                  Weight        76.7  2558-04-08 09:57:59.153
# 1                     BMI       30.76  2558-07-01 09:20:02.617
# 2              Pulse Rate          98  2558-07-01 09:20:02.617
# 3        Respiratory Rate          20  2558-07-01 09:20:02.617
# 4                     BMI       30.36  2558-07-22 10:04:54.377
# ...                   ...         ...                      ...
# 9213492      MeanPressure          82  2566-01-16 11:41:03.323
# 9213493       Systolic BP         141  2566-01-16 11:41:03.323
# 9213494  Respiratory Rate          22  2565-12-26 07:41:11.367
# 9213495       Systolic BP         155  2565-12-26 07:41:11.367
# 9213496  Respiratory Rate          18  2566-01-16 11:43:41.153
#
# [8099274 rows x 7 columns]

# %% [markdown]
# ### 🔎UniqueValues
# columns: **OrderItemName and ResultItemName** in vitalsign.csv

# %%
# Specify the columns for unique value counting
columns_to_count = ['OrderItemName', 'ResultItemName']

# Count unique values in the specified columns
unique_counts = vital[columns_to_count].value_counts().reset_index()

# %%
unique_counts.columns = ['OrderItemName','ResultItemName', 'Count']
unique_counts
# Out:
#          OrderItemName      ResultItemName    Count
# 0   Vital Signs Record         Systolic BP  1221173
# 1   Vital Signs Record        Diastolic BP  1220095
# 2   Vital Signs Record          Pulse Rate  1162366
# 3   Vital Signs Record    Respiratory Rate   913355
# 4   Vital Signs Record              Weight   601412
# 5   Vital Signs Record              Height   568598
# 6   Vital Signs Record         Temperature   565336
# 7   Vital Signs Record                 BMI   558791
# 8   Vital Signs Record                 BSA   558502
# 9   Vital Signs Record              O2 Sat   404864
# 10  Vital Signs Record          Pain Score   211445
# 11  Vital Signs Record        MeanPressure   105995
# 12  Vital Signs Record           Waistline     6032
# 13  Vital Signs Record  IrregularHeartBeat      960
# 14  Vital Signs Record  Head Circumference      246
# 15  Vital Signs Record                6MWT       85
# 16  Vital Signs Record  AverageMeasurement       10
# 17  Vital Signs Record                 Fat        9

# %%
unique_counts['ResultItemName'].unique()
# Out:
# array(['Systolic BP', 'Diastolic BP', 'Pulse Rate', 'Respiratory Rate',
#        'Weight', 'Height', 'Temperature', 'BMI', 'BSA', 'O2 Sat',
#        'Pain Score', 'MeanPressure', 'Waistline', 'IrregularHeartBeat',
#        'Head Circumference', '6MWT', 'AverageMeasurement', 'Fat'],
#       dtype=object)

# %%
selected_items = ['Systolic BP', 'Diastolic BP', 'Pulse Rate', 'Respiratory Rate',
                  'Temperature', 'Weight', 'Height', 'BSA', 'BMI']

filtered_items = unique_counts[unique_counts['ResultItemName'].isin(selected_items)]
filtered_items
# Out:
#         OrderItemName    ResultItemName    Count
# 0  Vital Signs Record       Systolic BP  1221173
# 1  Vital Signs Record      Diastolic BP  1220095
# 2  Vital Signs Record        Pulse Rate  1162366
# 3  Vital Signs Record  Respiratory Rate   913355
# 4  Vital Signs Record            Weight   601412
# 5  Vital Signs Record            Height   568598
# 6  Vital Signs Record       Temperature   565336
# 7  Vital Signs Record               BMI   558791
# 8  Vital Signs Record               BSA   558502

# %%
vitalsign_df = pd.DataFrame(filtered_items)
vitalsign_df
# Out:
#         OrderItemName    ResultItemName    Count
# 0  Vital Signs Record       Systolic BP  1221173
# 1  Vital Signs Record      Diastolic BP  1220095
# 2  Vital Signs Record        Pulse Rate  1162366
# 3  Vital Signs Record  Respiratory Rate   913355
# 4  Vital Signs Record            Weight   601412
# 5  Vital Signs Record            Height   568598
# 6  Vital Signs Record       Temperature   565336
# 7  Vital Signs Record               BMI   558791
# 8  Vital Signs Record               BSA   558502

# %% [markdown]
# ##🗂️Import data: Diagnosis

# %%
diagnosis
# Out:
#          PatientUID  PatientVisitUID ProblemCode  \
# 0             22496                0        K922
# 2              6629                0        K052
# 3             22234                0        E112
# 4             22234                0        N083
# 5             22234                0        E789
# ...             ...              ...         ...
# 2357567     3328161         10578100    82049002
# 2357570     3004348         10577134   312104005
# 2357571     3341752         10576249   128302006
# 2357572     3383466         10575890    56491003
# 2357573     3384941         10576181   255046005
#
#                                                ProblemName  \
# 0               Gastrointestinal haemorrhage\, unspecified
# 2                                      Acute periodontitis
# 3        Non-insulin-dependent diabetes mellitus type 2...
# 4        Glomerular disorders in diabetes mellitus ( E1...
# 5          Disorder of lipoprotein metabolism\,unspecified
# ...                                                    ...
# 2357567                            Squamous papillomatosis
# 2357570                Cholangiocarcinoma of biliary tract
# 2357571                                Chronic hepatitis C
# 2357572                                    Nephrolithiasis
# 2357573                              Neuroendocrine tumour
#
#                                         ProblemDescription  \
# 0         เลือดออกในกระเพาะอาหารและลำไส้ ไม่ระบุรายละเอียด
# 2                             โรคปริทันต์อักเสียบเฉียบพลัน
# 3        เบาหวานชนิดที่ไม่ต้องพึ่งอินซูลิน ร่วมกับภาวะแ...
# 4        ความผิดปกติของโกลเมอรูลัสในโรคเบาหวาน (E10-E14...
# 5        ความผิดปกติแบบอื่นของเมตะบอลิซึมของไลโปโปรตีน ...
# ...                                                    ...
# 2357567                                                NaN
# 2357570                                                NaN
# 2357571                                                NaN
# 2357572                                                NaN
# 2357573                                                NaN
#
#                                   DIAGTYPE                OnsetDttm
# 0        PRINCIPAL DX (การวินิจฉัยโรคหลัก)  2556-01-05 00:00:00.000
# 2        PRINCIPAL DX (การวินิจฉัยโรคหลัก)  2556-01-05 00:00:00.000
# 3        PRINCIPAL DX (การวินิจฉัยโรคหลัก)  2556-01-07 00:00:00.000
# 4        PRINCIPAL DX (การวินิจฉัยโรคหลัก)  2556-01-07 00:00:00.000
# 5        PRINCIPAL DX (การวินิจฉัยโรคหลัก)  2556-01-07 00:00:00.000
# ...                                    ...                      ...
# 2357567  PRINCIPAL DX (การวินิจฉัยโรคหลัก)  2566-04-11 00:00:00.000
# 2357570  PRINCIPAL DX (การวินิจฉัยโรคหลัก)  2566-04-11 00:00:00.000
# 2357571  PRINCIPAL DX (การวินิจฉัยโรคหลัก)  2566-04-11 00:00:00.000
# 2357572  PRINCIPAL DX (การวินิจฉัยโรคหลัก)  2566-04-11 00:00:00.000
# 2357573  PRINCIPAL DX (การวินิจฉัยโรคหลัก)  2566-04-11 00:00:00.000
#
# [2081658 rows x 7 columns]

# %% [markdown]
# ### 🔎**UniqueValues**
# columns: **ProblemCode, ProblemName, and (ProblemCode,ProblemName)** in Diagnosis.csv

# %%
diag_code = diagnosis['ProblemCode'].value_counts().reset_index()
diag_code.columns = ['UniqueValue_CODE','Count']
diag_code
# Out:
#       UniqueValue_CODE   Count
# 0            370992007  124827
# 1                  I10   90673
# 2             44054006   68739
# 3              1201005   66796
# 4             59621000   51308
# ...                ...     ...
# 18771        269095002       1
# 18772        312902008       1
# 18773         41801008       1
# 18774             H619       1
# 18775         95209008       1
#
# [18776 rows x 2 columns]

# %%
diag_name = diagnosis['ProblemName'].value_counts().reset_index()
diag_name.columns = ['UniqueValue_NAME','Count']
diag_name
# Out:
#                                         UniqueValue_NAME   Count
# 0                                           Dyslipidemia  124826
# 1                       Essential (primary) hypertension   90673
# 2                               Type 2 diabetes mellitus   68737
# 3                          Benign essential hypertension   66802
# 4                                 Essential hypertension   52005
# ...                                                  ...     ...
# 17751                               Infantile hemiplegia       1
# 17752  Influenza with other manifestations\, virus no...       1
# 17753  Vascular complications following a procedure\,...       1
# 17754         Chronic instability of knee Multiple sites       1
# 17755                  Plasma cell leukemia in remission       1
#
# [17756 rows x 2 columns]

# %%
# Specify the columns for unique value counting
columns_to_count = ['ProblemCode', 'ProblemName']

# Count unique values in the specified columns
diag_count = diagnosis[columns_to_count].value_counts().reset_index()
diag_count.columns = ['ProblemCode', 'ProblemName', 'Count']
diag_count
# Out:
#       ProblemCode                                        ProblemName   Count
# 0       370992007                                       Dyslipidemia  124826
# 1             I10                   Essential (primary) hypertension   90673
# 2        44054006                           Type 2 diabetes mellitus   68737
# 3         1201005                      Benign essential hypertension   66796
# 4        59621000                             Essential hypertension   51307
# ...           ...                                                ...     ...
# 18914    31137003  Early latent syphilis, positive serology, nega...       1
# 18915   311804006  Prolapsed lumbar intervertebral disc with scia...       1
# 18916   125587004                                 Superficial injury       1
# 18917   311892004       Collapse of vertebra due to osteoporosis NOS       1
# 18918   188064009                       Malignant melanoma of finger       1
#
# [18919 rows x 3 columns]

# %%
diag_df = pd.DataFrame(diag_count)
diag_df
# Out:
#       ProblemCode                                        ProblemName   Count
# 0       370992007                                       Dyslipidemia  124826
# 1             I10                   Essential (primary) hypertension   90673
# 2        44054006                           Type 2 diabetes mellitus   68737
# 3         1201005                      Benign essential hypertension   66796
# 4        59621000                             Essential hypertension   51307
# ...           ...                                                ...     ...
# 18914    31137003  Early latent syphilis, positive serology, nega...       1
# 18915   311804006  Prolapsed lumbar intervertebral disc with scia...       1
# 18916   125587004                                 Superficial injury       1
# 18917   311892004       Collapse of vertebra due to osteoporosis NOS       1
# 18918   188064009                       Malignant melanoma of finger       1
#
# [18919 rows x 3 columns]

# %% [markdown]
# ##🗂️Import data: Lab

# %%
lab
# Out:
#           LabNo  PatientUID  PatientVisitUID  \
# 0             1        2299          2024049
# 1             1        2299          2024049
# 2             1        2299          2024049
# 3             1        2299          2024049
# 4             1        2299          2024049
# ...         ...         ...              ...
# 21641153    601      822860          5140446
# 21641156    602      822860          5140446
# 21641159    603      822860          5140446
# 21641162    604      822860          5140446
# 21641165    605      822860          5140446
#
#                                            Location   RequestItemName  \
# 0                     เวชศาสตร์นิวเคลียร์ (OPD)-D15        BMD LUMBAR
# 1         ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร    ALBUMIN, 32403
# 2         ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร     Alkaline Phos
# 3         ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร        ALT, 32311
# 4         ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร        AST, 32310
# ...                                             ...               ...
# 21641153  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร  Dextrostix(POCT)
# 21641156  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร  Dextrostix(POCT)
# 21641159  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร  Dextrostix(POCT)
# 21641162  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร  Dextrostix(POCT)
# 21641165  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร  Dextrostix(POCT)
#
#             ResultItemName                    CWhen ResultDttm ResultValue  \
# 0         Formatted Result  2558-02-19 16:16:51.423        NaN          FT
# 1           ALBUMIN, 32403  2558-02-19 10:32:20.907        NaN         4.1
# 2               ALP, 32309  2558-02-19 10:32:21.610        NaN          44
# 3               ALT, 32311  2558-02-19 10:32:21.390        NaN          17
# 4               AST, 32310  2558-02-19 10:32:21.500        NaN          23
# ...                    ...                      ...        ...         ...
# 21641153         DTX(POCT)  2561-10-19 11:00:42.207        NaN         228
# 21641156         DTX(POCT)  2561-10-19 17:24:45.417        NaN         240
# 21641159         DTX(POCT)  2561-10-19 22:40:42.073        NaN         171
# 21641162         DTX(POCT)  2561-10-20 05:39:12.677        NaN         191
# 21641165         DTX(POCT)  2561-10-20 10:53:23.537        NaN         308
#
#            Unit ReferenceRange
# 0           NaN            NaN
# 1           NaN      3.8 - 5.4
# 2           NaN       42 - 121
# 3           NaN         4 - 36
# 4           NaN        12 - 32
# ...         ...            ...
# 21641153  mg/dL              -
# 21641156  mg/dL              -
# 21641159  mg/dL              -
# 21641162  mg/dL              -
# 21641165  mg/dL              -
#
# [17728574 rows x 11 columns]

# %% [markdown]
# ### 🔎**UniqueValues**
# columns: **Location and ResultItemName** in Lab.csv

# %%
lab_location = lab['Location'].value_counts().reset_index()
lab_location.columns = ['Location', 'Location_Count']

lab_result = lab['ResultItemName'].value_counts().reset_index()
lab_result.columns = ['ResultItemName', 'ResultItemName_Count']

lab_request = lab['RequestItemName'].value_counts().reset_index()
lab_request.columns = ['RequestItemName', 'RequestItemName_Count']

columns_to_count = ['Location', 'ResultItemName', 'RequestItemName']

# Count unique values in the specified columns
lab_count = lab[columns_to_count].value_counts().reset_index()
lab_count.columns = ['Location', 'ResultItemName', 'RequestItemName', 'Count']

lab_df = pd.DataFrame(lab_count)

lab_location = lab['Location'].value_counts().reset_index()
lab_location.columns = ['Location','Count']
lab_result = lab['ResultItemName'].value_counts().reset_index()
lab_result.columns = ['ResultItemName','Count']

# Specify the columns for unique value counting
columns_to_count = ['Location', 'ResultItemName']

# Count unique values in the specified columns
lab_count = lab[columns_to_count].value_counts().reset_index()
lab_count.columns = ['Location', 'ResultItemName', 'Count']
lab_count
# Out:
#                                        Location          ResultItemName  \
# 0     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร       CREATININE, 32202
# 1               ห้องปฏิบัติการจุลทรรศน์วินิจฉัย                   WBC
# 2               ห้องปฏิบัติการจุลทรรศน์วินิจฉัย                   RBC
# 3     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร  eGFR(CKD-EPI) age >=18
# 4     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร        POTASSIUM, 32103
# ...                                         ...                     ...
# 1805  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร                     HE4
# 1806       ห้องปฏิบัติการภูมิคุ้มกันวิทยาคลินิก           Microsomal Ab
# 1807       ห้องปฏิบัติการภูมิคุ้มกันวิทยาคลินิก                Mosquito
# 1808  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร                    HCO3
# 1809                           OPD Anest (SPAC)                   BE(B)
#
#        Count
# 0     492979
# 1     476097
# 2     476049
# 3     435224
# 4     419305
# ...      ...
# 1805       1
# 1806       1
# 1807       1
# 1808       1
# 1809       1
#
# [1810 rows x 3 columns]

# %% [markdown]
# ##🗂️Import data: Prescription

# %%
df = pd.DataFrame(prescription)
df
# Out:
#          PatientUID  PatientVisitUID            DispensedDttm  \
# 0              2299          2024049  2558-02-19 14:48:15.693
# 1              2299          2024049  2558-02-19 14:48:15.693
# 2              2299          2024049  2558-02-19 14:48:15.693
# 3              2299          2024049  2558-02-19 14:48:15.693
# 4              2299          2024049  2558-02-19 14:47:55.953
# ...             ...              ...                      ...
# 9530447     3437526         10191122  2565-12-27 03:00:00.563
# 9530448     3437526         10191122  2565-12-27 03:00:00.563
# 9530449     3437526         10191122  2565-12-27 03:00:00.563
# 9530450     3437526         10191122                      NaN
# 9530451     3437526         10191122                      NaN
#
#                                                   DrugName  \
# 0                                      Folic Acid 5 mg TAB
# 1                                    Vitamin B Complex TAB
# 2                              losartan(Loranta) 50 mg TAB
# 3                             lorazepam(Anxira) 0.5 mg TAB
# 4                                         ChalkTAB-1.5 TAB
# ...                                                    ...
# 9530447                   Infusion plabottle set (IV.set)
# 9530448                      Normal Saline 0.9% IV 1000 ml
# 9530449                       Normal Saline 0.9% IV 100 ml
# 9530450          Minimun Volume Extension with T connector
# 9530451  Intravenous Disposable Catheter ch.20 ความยาวป...
#
#                            GenericName  Quantity  \
# 0                     Folivit tab 5 mg      90.0
# 1                Vitamin B Complex TAB     180.0
# 2        Loranta film-coated tab 50 mg      90.0
# 3                    Anxira tab 0.5 mg      30.0
# 4                     Chalktab 1500 mg      90.0
# ...                                ...       ...
# 9530447                            NaN       2.0
# 9530448  Normal Saline 0.9% IV 1000 ml       1.0
# 9530449   Normal Saline 0.9% IV 100 ml       2.0
# 9530450                            NaN       1.0
# 9530451                            NaN       1.0
#
#                                     DrugFrequency  Dosage DosageForm  \
# 0              od pc |วันละ 1 ครั้ง หลังอาหารเช้า     1.0      1 TAB
# 1        bid pc |วันละ 2 ครั้ง หลังอาหารเช้า เย็น     1.0      1 TAB
# 2              od pc |วันละ 1 ครั้ง หลังอาหารเช้า     1.0      1 TAB
# 3                       hs |วันละ 1 ครั้ง ก่อนนอน     1.0      1 TAB
# 4              od pc |วันละ 1 ครั้ง หลังอาหารเช้า     1.0      1 TAB
# ...                                           ...     ...        ...
# 9530447                                       NaN     NaN        NaN
# 9530448                As Direct |ใช้ตามแพทย์สั่ง     NaN       0 ml
# 9530449                As Direct |ใช้ตามแพทย์สั่ง     NaN       0 ml
# 9530450                                       NaN     NaN        NaN
# 9530451                                       NaN     NaN        NaN
#
#          DrugDuration
# 0                90.0
# 1                90.0
# 2                90.0
# 3                30.0
# 4                90.0
# ...               ...
# 9530447           1.0
# 9530448           1.0
# 9530449           1.0
# 9530450           1.0
# 9530451           1.0
#
# [9530452 rows x 10 columns]

# %% [markdown]
# ### **🔎UniqueValues**
# columns: **DrugName, GenericName, and (DrugName,GenericName)** in Prescription.csv

# %%
import pandas as pd
import re

# Lowercase and store values from 'DrugName' column
drugCol1 = [str(i).lower() for i in df['DrugName']]

# Lowercase and store values from 'GenericName' column
genericCol1 = [str(i).lower() for i in df['GenericName']]

# Store drug names
drugCol2 = []
genericCol2 = []
drugdigits = []

# Process 'DrugName' column
for value in drugCol1:
    if isinstance(value, str):
        if value[0].isdigit():
            # Store the value starting with digits in drugdigits list
            drugdigits.append(value)
            # Remove the dose quantity and store in drugCol2 list
            newval = re.sub(r'\b\d+(\.\d+)?\s*[a-zA-Z]+\s*', '', value)
            drugCol2.append(newval)
        else:
            valList = value.split()
            index_begin_with_digit = len(valList)
            for i in range(len(valList)):
                if valList[i][0].isdigit():
                    index_begin_with_digit = i
                    break
            newval = " ".join(valList[:index_begin_with_digit])
            drugCol2.append(newval)


# Process 'GenericName' column
for value in genericCol1:
    if isinstance(value, str):
        if value[0].isdigit():
            genericCol2.append(value)
        else:
            valList = value.split()
            index_begin_with_digit = len(valList)
            for i in range(len(valList)):
                if valList[i][0].isdigit():
                    index_begin_with_digit = i
                    break
            newval = " ".join(valList[:index_begin_with_digit])
            genericCol2.append(newval)

# Replace unwanted words and remove words starting with 'no.' and the digits following them
words_to_remove = ['inj', 'cap', 'mg', 'ml', 'tab', '[7402]', '[5702]', '[5703]', '[0604]', '[5606]', '[024840]', '[napha]', '[5704]', '(ฝาก)', '(เลิกใช้)']

drugCol3 = []
for i in drugCol2:
    for word in words_to_remove:
        i = i.replace(word, "")
    i = re.sub(r'\bno\.\d+(\.\d+)?\b', '', i)
    drugCol3.append(i.strip())

set(drugCol3)
# Out:
# {'',
#  'ท่อนำสายสวนเข้าหลอดเลือด (introducer sheath)',
#  'amikacin(gpo)',
#  'fluomizin',
#  'สายลวดนำสายสวนเพื่อการขยายหลอดเลือดแดงส่วนปลาย bentson wire guide',
#  'แถบตรวจน้ำตาลปลายนิ้ว รุ่น gs700 (rightest blood glucose test strip gs700)',
#  'เฝือกพยุงระดับเอวback support no. m ขนาดรอบเอว',
#  'cocr coronary stent system size',
#  'biolimus a9tm -eluting stent system size',
#  'vehicle for omeprazole',
#  'แผ่นโลหะดามกระดูก ชนิดมีหัวสกรูพยุง (locking plate) lcp reconstruction plate',
#  'ท่อระบายน้ำดีชนิดพลาสติก ท่อระบายน้ำดีชนิดพลาสติก',
#  'carboplatin(kemocarb)',
#  'synvisc',
#  'duoderm',
#  'kamilosan-m spray',
#  'guide wire fixed core',
#  'airselect short, s',
#  'ชุดสายสวนกระเพาะอาหารแบบใส่ผ่านกล้องกรณีเปลี่ยนเฉพาะสาย non-balloon replacement gastrostomy tube',
#  'สายลวดนำสายสวนเพื่อการขยายหลอดเลือดแดงส่วนปลาย (peripheral angioplasty guide wire) adventage peripheral g/w',
#  'ห่วงอนามัย pessary ring',
#  'เครื่องช่วยการเต้นของหัวใจถาวรชนิดกระตุ้นหัวใจห้องเดียวปรับอัตราการเต้นอัตโนมัติ สามารถเข้าเครื่อง mri ได้ (single chamber pacemaker with rate responsive mri compatible) :ensurasr mri',
#  'simulect',
#  'vascular sequential compression tubing (sengstaken)',
#  'sanoskin melladerm plus(topical antimicrobial honey dressing)',
#  'bioflor',
#  'methylprednisolone',
#  'carminative mixture',
#  'สายให้อาหารปั่นพร้อมปุ่มควบคุมการไหล ยาว',
#  'midorine',
#  'vocinti',
#  'สายสวนหลอดเลือดขนาดเล็กและยาวพิเศษเพื่อการรักษา (magic1.2fm',
#  'cresemba',
#  'จุกปิด t-way',
#  'cardiprin',
#  'azithromycin(zithrotel)',
#  'cinacalcet(calcelar)',
#  'ตัวกรองไตเทียมแบบประสิทธิภาพสูง ตัวกรอง infomed (acute) - [ucs/sss]',
#  'mdi adaptor สำหรับผู้ใหญ่ใช้กับเครื่องช่วยหายใจ',
#  'สายเครื่องช่วยกระตุ้นหัวใจชนิดถาวร (pacemaker lead) :5076 -58 cm',
#  'lipitor',
#  'gaszym',
#  'duoderm gel',
#  'ชุดสายยางประกอบการไหลเวียนนอกร่างกายผู้ใหญ่',
#  'ekg electrod สำหรับrun ekg.infant',
#  'colostomy bag',
#  'metoprolol',
#  'flixonase nasal spray',
#  'uromitexan',
#  'viartril-s',
#  'เข็มตัดชิ้นเนื้อ qcs-20 –9.0 -',
#  'ตัวกรองไตเทียมแบบประสิทธิภาพสูง plasmaflo (baxter) (acute) - [ucs/sss]',
#  'ชุดปอดเทียมผู้ใหญ่ ชนิดใช้งานระยะยาว (adult oxygenator for ecmo)',
#  'ถุงคลุมฉากกั้นแบบปากถุงมีสายรัดยางยืด ขนาด',
#  'central venous catheter single lumen',
#  'สำลี20ก้อน/ซอง',
#  'cidofovir(emcure)',
#  'เครื่องช่วยฟังสำหรับคนหูพิการแบบทัดหลังใบหู รุ่น aries',
#  'หน้ากากครอบจมูกหรือปากที่ใช้กับเครื่องอัดอากาศขณะหายใจเข้า ชนิดครอบจมูก (nasal mask) รุ่น airfit n20 classic size l',
#  'multivitamin drop',
#  'imipramine(minapine)',
#  'เครื่องมือจี้ห้ามเลือดผนึกหลอดเลือด re- harmonic focus blade,',
#  'สายสวนเพื่อระบายของเหลวหรือลมออกจากร่างกายผ่านผิวหนังขนาด',
#  'adalat cr',
#  'hyruan one',
#  'clonazepam(prenapil)',
#  'cardura xl',
#  'กระบอกปัสสาวะชาย urinal',
#  'ถุงมือผ่าตัด sterile เบอร์6 แบบมีแป้ง',
#  'sandimmun neoral solution',
#  'milk of magnesia(gpo) suspension',
#  'ivig',
#  'มีดเจาะลูกตา slit knife',
#  'ขดลวดปิดกั้นหลอดเลือด (coils) mwce-35-14-12-nester',
#  "lactate ringer's",
#  'liq. carbonis detergent cream',
#  'หลอดคอช่วยการหายใจชนิดทำด้วยโลหะที่ไม่ขึ้นสนิม stainless tracheostomy tube,,',
#  'efavirenz(gpo)',
#  'สายลวดนำสายสวนชนิดมีความยาวพิเศษ smooth guide straight .035-260',
#  'ขดลวดอุดกั้นหลอดเลือดชนิดปลดด้วยลวดผลักดัน vortx-18 -fiber platinum coil',
#  'เจลหล่อลื่นและให้ความชุ่มชื้นในช่องคลอดชนิดติดทนนาน',
#  'บอลลูนถ่างขยายทางเดินอาหาร esophageal balloon dilator with wire guide10-12 (เวชภัณฑ์)',
#  'ลวดนำสายสวนหลอดเลือดเพื่อการขยายหลอดเลือดแดงส่วนปลาย guide wire gt',
#  'mevac-a',
#  'salazopyrin en',
#  'jevtana',
#  'hbig(hepatitis b ig)',
#  'glycerin enema',
#  'hemoclip ขนาดมาตรฐาน (90 องศา)รุ่น hx-610-090l(ชมพู)',
#  'โลหะดามกระดูกและใส่โพรงกระดูก ชนิดแยกชิ้น (nail short stem +lag screw1 ตัว+distal screw1ตัว)',
#  'ผ้ายืดพยุงสะโพก ทูบีกริบสะโพก (tubigrip) no. l รอบสะโพก',
#  'สายสวนหลอดเลือดฉีดสีหลอดเลือดหัวใจโคโรนารี angiographic catheter size al-2 ,',
#  'caraten',
#  'clopixol-acuphase',
#  'temodal 100  [xt0016](เฉพาะ)',
#  'lac-oph',
#  'แผ่นปิดรักษาแผลเปื่อยเฉพาะผู้ป่วยมีแผลเปื่อยจากการมีลำไส้เปิดหน้าท้องcutinova',
#  'แผ่นโลหะดามกระดูก ชนิดมีหัวสกรูพยุง (locking plate) lcp for proximal tibial',
#  'เครื่องมือเย็บและตัดต่ออัตโนมัติชนิดปรับหัวได้ ไส้เครื่องมือตัดต่อลำไส้อัตโนมัติ แบบโค้ง (contour)',
#  'แผ่นโลหะดามกระดูก ชนิดมีหัวสกรูพยุง (locking plate) lcp plate',
#  'lamictal',
#  'กรรไกรขนาดเล็กสำหรับตัดน้ำวุ้นตา',
#  'selbex',
#  'absorbable monofilament polyglyconate v-lock อุปกรณ์เย็บปิดแผลชนิดมีหนามยึด เบอร์',
#  'gelatin sponge absorbable sterile size',
#  'intravenous disposable catheter ch.20',
#  'เครื่องช่วยฟังสำหรับคนหูพิการแบบกล่อง รุ่น clip3bw-pvi',
#  'voltaren',
#  'adrenaline',
#  'endotracheal tube  มี cuff',
#  'ผ้ายืดพยุงข้อเข่าelastic knee support m',
#  'tube culture plastic size',
#  'ตัวเจาะหน้าท้อง',
#  'อุปกรณ์สำหรับดัดนิ้วเท้าในช่วงกลางคืน (hallux valgus night splint) สำหรับดัดนิ้วโป้งเอียง',
#  'ตัวกรองไตเทียมพร้อมชุดสายยางนำเลือดสำหรับการทำ crrt ประกอบเครื่อง aquarius machine',
#  'tolvon',
#  'cannula vessel',
#  'cycloserine',
#  'sodamint',
#  'อุปกรณ์ซ่อมปิดหลอดเลือด อุปกรณ์หยุดเลือดที่ femoral artery proglide',
#  'แผ่นโลหะดามกระดูกชนิดเล็ก mini bone plate l-shape,left-medium mini l plate left medium',
#  'bicalutamide',
#  'ข้อเข่าชนิดที่ส่วนรับน้ำหนักไม่สามารถเคลื่อนไหวได้ genesis ii p/s ไม่รวม patella',
#  'continuous epidural set pediatric',
#  'triumeq',
#  'ข้อตะโพกมีเบ้า(total hip prosthesis)รวมทั้งอุปกรณ์เสริม cemented/tha-excia stem + metal head',
#  'สายสวนหลอดเลือดนำทางเพื่อการขยายหลอดเลือดโคโรนารี guiding catheter al-0.75',
#  'd2',
#  'สายสวนหัวใจและหลอดเลือดเพื่อการวินิจฉัย diagnostic catherter (hnbr5.0-38-65-p-ns-rim)',
#  'monofilament polypropylene /0 เข็ม',
#  'เบ้าสะโพกโลหะแบบมีรูพรุน(hyperporus aceular cup)',
#  'ท่อนำสายสวนเข้าหลอดเลือดชนิดยาวพิเศษ raabe flexor (kcfw6.0-38-55-rb-hfanli-hc)',
#  'กอซไม่พับ / ซอง',
#  'โลหะดามกระดูกและใส่โพรงกระดูก ชนิดแยกชิ้น proximal femoral nail ( pfna)',
#  'ข้อเข่าชนิดที่ส่วนรับน้ำหนักไม่สามารถเคลื่อนไหวได้ gem รวม patella',
#  'เฝือกพยุงระดับเอว back support no. s',
#  'n.s.s.irrigate',
#  'cavafix catheter',
#  'multivitamin',
#  'aluminium splint size',
#  'สารอุดกั้นหลอดเลือดชนิดเหลวแบบแข็งตัวเร็ว histoacryl glue tissue adhesive (เวชภัณฑ์)',
#  'ไหมเย็บแผล ชนิดเส้นเดี่ยว ไม่ละลายน้ำ ผลิตจากโพลีโพรไพลีน  จำนวน2 เส้น (1 blue,',
#  'intravenous disposable catheter ch.16 (premium)',
#  'หลอดเลือดเทียมสำหรับการผ่าตัดหลอดเลือดส่วนปลาย ptfe vascular graft',
#  're-trapezoid biliary stone retrieval basket',
#  'สายคล้องแขน arm sling no. s วัดความยาวแขนท่อนล่างจากปลายนิ้วก้อยถึงข้อศอก',
#  'อุปกรณ์พยุงข้อมือหรือนิ้ว wrist support no. m',
#  'hydrogen peroxide',
#  "marking pen's disposable sterile pack ruler(ปากกา/ไม้บรรทัด)",
#  'ขอบลิ้นหัวใจเทียม c-e physio no.',
#  'aquacel ag',
#  'ถุงน่องแรงดัน20-30mmhgระดับใต้เข่า สีดำ (เส้นรอบน่อง30-34ซม.)',
#  'ท่อใส่เยื่อแก้วหู (myringotomy tube) แบบ t-tube silicone, length',
#  'ensure chocolate',
#  'orkelax',
#  'daivonex ointment',
#  'clear-trac threaded cannula with obturator',
#  'kivexa(600/300) ฺ (เฉพาะ)',
#  'portex adjusle flange tracheostomy , id',
#  'omeprazole(gpo)',
#  'hidrasec paediatric',
#  'แผ่นใยสังเคราะห์แทนผนังหน้าท้องชนิดเมมเบรน ความยาว',
#  'vesanoid',
#  'magnesium sulfate',
#  'ไม้ค้ำยัน เบอร์',
#  'ข้อเข่าชนิดที่ส่วนรับน้ำหนักไม่สามารถเคลื่อนไหวได้ pfc sigma + modular tray รวม patella',
#  'novorapid penfill',
#  'thalidomide(thado)',
#  'ozudrex',
#  'doperan susp',
#  'benzac ac',
#  'สายสวนหลอดเลือดเพื่อการวินิจฉัย imager ii -sim2 fr.5 - .035 -',
#  'ที่ครอบตา ซ้าย/ขวา',
#  'votrient',
#  'glucerna sr',
#  'เลนส์แก้วตาเทียมชนิดพับได้แก้ไขสายตาเอียง alcon รุ่น toric sn d1t5, single piece, a-con',
#  'proctoscope ใหญ่',
#  'แผ่นปิดรักษาแผลเปื่อยเฉพาะผู้ป่วยมีแผลเปื่อยจากการมีลำไส้เปิดหน้าท้องaquacel ag',
#  'ti-cron',
#  'สายสวนเพื่อการขยายหลอดเลือดแดงส่วนปลายด้วยบอลลูน ทนแรงดันมากกว่า',
#  'betamethasone(gpo) cream',
#  'cold cream (heb)',
#  'sat.ki. solution',
#  'zepatier',
#  'favipiravir',
#  'ท่อชั้นนอกตัวเจาะหน้าท้อง',
#  'spiriva c handihaler',
#  'xarelto',
#  'แผ่นปิดรักษาแผลหลังผ่าตัด ชนิดเคลือบซิลิโคน mepilex border post-op ขนาด',
#  'สายล้างไต สายส่ง plasmaflo',
#  'ชุดพ่นยา o2 mask (ผู้ใหญ่)',
#  'fucithalmic eye drop',
#  'tebonin forte',
#  'xanthium',
#  'arixtra',
#  'olumiant',
#  'syringe disposable',
#  'ถุงมือผ่าตัดชนิดปราศจากเชื้อ ไม่มีแป้ง ผลิตจากสาร neoprene สำหรับผู้แพ้ยางดิบธรรมชาติ no.',
#  'hirsuit hair tonic spray',
#  'สายสวนปัสสาวะชนิดใช้ในไต multiperpose drainage catheter',
#  'monofilament nonabsorbable polybutester',
#  'mamofen',
#  'neo muneขนาดบรรจุ',
#  'actrapid hm',
#  'lotemax',
#  'สายสวนเพื่อการขยายหลอดเลือดโคโรนารี่ด้วยขดลวดเคลือบยาต้านการตีบซ้ำ (drug-eluting stent) synergy dia.2.5x32mm.',
#  'สายสวนหลอดเลือดขนาดเล็ก และยาวพิเศษ (micro catheter; merit maestro) เคลือบสาร hydrophilic distal',
#  'mezavant xl',
#  'chirocaine',
#  'ขดลวดปิดกั้นหลอดเลือด vortx diamond fiber platinum coil',
#  'tidar',
#  'lugen tube size',
#  'endovascular dilator set (jcds-2022-esd-hc)',
#  'อุปกรณ์พยุงเข่า ชนิดไม่มีแกน ผ้ายืด knee support m',
#  'renvela',
#  'k.k. balm',
#  'livact granules',
#  'plastic kafo size l (พลาสติกดามขาขนาดใหญ่มีข้อเข่าล๊อกได้)',
#  'แผ่นโลหะดามกระดูกชนิดมีหัวสกรูพยุง (lock plate) arix wrist system / volar distal radius locking plate, volar rim type',
#  'desferal',
#  'proxima colos-drainable bag',
#  'inlyta',
#  'coronary sinus pacing lead -88 cm attain performa',
#  'influenza vaccine(vaxigrip tetra)',
#  'gpo-a-flu',
#  'สายสวนเพื่อการขยายหลอดเลือดโคโรนารี่ด้วยขดลวดเคลือบยาต้านการตีบซ้ำ zotarolimus-eluting coronary stent system size',
#  'ptca guide wire',
#  'pentaxim',
#  'ถุงมือใช้แล้วทิ้ง ชนิดทำจากยางพารา เบอร์ s (50คู่/box)',
#  'เฝือกพยุงคอชนิดอ่อน soft collar no. m วัดรอบคอ',
#  'blade for dermatome cutting,',
#  'trileptal',
#  'อุปกรณ์สำหรับพ่นยา mdi holding chamber (ace kit)',
#  'intravenous disposable catheter ch.22 ความยาวประมาณ',
#  'sixime',
#  'ขดลวดพร้อมอุปกรณ์สำหรับปล่อยชนิดปลดได้ (inter locking coil)',
#  'blade surgical',
#  'propylthiouracil',
#  'synthetic absorbable -0 ยาวไม่น้อยกว่า',
#  'ขวดราดิแวคขนาด',
#  'unison enema solution',
#  'vincristine pharmacia',
#  'เครื่องช่วยฟังสำหรับคนหูพิการแบบทัดหลังใบหู รุ่น naida s i sp',
#  'hydrophilic wire guide',
#  'มีดเจาะลูกตา crescent knife angle, bevel up (',
#  'สายล้างไต สายส่ง infomed หรือ set crrt (acute)',
#  'vigamox eye drop',
#  'neohydro fr',
#  'สายสวนเพื่อการขยายหลอดเลือดส่วนปลายด้วยขดลวด peripheral stent balloon-expandable monorail size',
#  'zometa',
#  'hydrocellular foam dressing ag with antimicrobial',
#  'transparent dressing ขนาด',
#  'เข็มตัดชิ้นเนื้อ semiauto.biop.with coxial',
#  'คีมหนีบหลอดเลือดโป่งพองในช่องกะโหลกศรีษะ ชนิดรูปร่างพิเศษ (fenestrate clip)',
#  'wound supports and supplies and accessories',
#  'puncture needle (18gx7cm) ad18171wt',
#  'ปรอทวัดไข้ทางปาก',
#  'zytiga',
#  'monofilament nonabsorbable',
#  'ขดลวดสำหรับปิดรูรั่ว mwce-35-14-8-nester',
#  'sodium bicarbonate',
#  'เก้าอี้นั่งถ่าย l',
#  'กล่องแม่เหล็กเก็บเข็มและใบมีดผ่าตัด',
#  'แอ่งบรรจุเลือด terumo (terumo bio head) (เวชภัณฑ์)',
#  'conforming streth bandage',
#  'phenobarbitone',
#  'truvada',
#  'neotigason',
#  'สายสวนหลอดเลือดช่องท้อง yashiro type fr.5 -.038 -',
#  'erythomycin',
#  'sulfasalazine(salazine)',
#  'zalain',
#  'd-10-s',
#  'สายสวนหลอดเลือดนำทางเพื่อการขยายหลอดเลือดโคโรนารี guiding catheter jr4 sh',
#  'mircera',
#  'abacavir/lamivudine(mylan)',
#  'สายสวนหลอดเลือดนำทางสำหรับการขยายหลอดเลือดแดงส่วนปลาย (peripheral guiding catheter) ขนาดเล็กส่วนปลายเคลือบด้วย hydrophilic ขนาด',
#  'victoza',
#  'mini,transfer set (bax)(ฝาก',
#  'สายสวนเพื่อการขยายหลอดเลือดโคโรนารี่ด้วยขดลวดเคลือบยาต้านการตีบซ้ำ (drug-eluting stent) synergy dia.3.5x12mm.',
#  'androgel gel (เฉพาะ)',
#  'หลอดเลือดเทียมสำหรับการผ่าตัดหลอดเลือดแดงใหญ่แบบเส้นแยก vascular graft bifurcate diameter',
#  'defebrillation electrode pad สำหรับเครื่องกระตุกหัวใจ ยี่ห้อ phillip',
#  'สายลวดนำสายสวนเพื่อการขยายหลอดเลือดแดงส่วนปลาย guide wire ขนาด',
#  'reyataz',
#  'nutren balance',
#  'ท่อต่อหลอดเลือดดำ straight single stage ขนาด',
#  'd-5-1/4 s',
#  'ท่อนำสายสวนเข้าหลอดเลือด introducer sheath (pro-8f-11-035)',
#  'monofilament polypropylene',
#  'ensure vanilla',
#  'natear',
#  'สายต่อท่อใส่เข้าท้องแบบถาวร กับถุงน้ำยาแบบธรรมดา (transferred set) miniสำหรับทำ d',
#  'sho',
#  'suction with control catheter ch.16',
#  'เครื่องช่วยฟังสำหรับคนหูพิการแบบทัดหลังใบหู รุ่น flow',
#  'ลวดนำสายสวนหลอดเลือดเพื่อการขยายหลอดเลือดแดงส่วนปลาย (fathom fr.016 steerable guide wire',
#  'alkeran',
#  'fulvestrant(sandoz)',
#  'แท่งโลหะดามกระดูกขากรรไกร imf screw dia',
#  'metoclopamide',
#  'xyzal',
#  'สายสวนหลอดเลือดเพื่อการวินิจฉัย (vascular diagnostic catheter) pig ,',
#  'เลนส์แก้วตาเทียมชนิดพับได้แก้ไขสายตาเอียง alcon รุ่น toric sn6at3 , single piece, a-con',
#  'ท่อถ่างขยายหลอดอาหารแบบมีหรือไม่มีเมมเบรนหุ้ม esophageal stent',
#  'indomethacin',
#  'vivacor',
#  'puroxan',
#  'ก๊อสไม่พับพิเศษ ปลอดเชื้อ ขนาด',
#  'gpo-vir t',
#  'glucose powder',
#  'glucobay',
#  'schanz screw diameter',
#  'rifampicin',
#  'oxitan',
#  'เข็มเจาะดูดเนื้อเยื้อผ่านกล้องส่องตรวจชนิดอัลตราซาวด์ เข็ม endoscopic u/s guide fna (22g)',
#  'crestor',
#  'samnir',
#  'ผ้ายืดประคองเข่า no. l รอบเข่า',
#  'notrixum',
#  'avodart',
#  'สายเครื่องช่วยกระตุ้นหัวใจชนิดถาวร (pacemaker lead) :4076 -58 cm',
#  'ผลิตภัณฑ์ทำความสะอาดเปลือกตา ocusoft plus foaming',
#  'รองเท้าสำหรับผู้ป่วยเบาหวานที่มีความเสี่ยง เพื่อป้องกันการเกิดแผล, แผลซ้ำซ้อน และการตัดเท้า',
#  'glivec',
#  'syringe irr',
#  'รองเท้าดัดแปลงสำหรับผู้ป่วยเบาหวาน ที่มีการชาที่เท้าหรือเท้าผิดรูป (off-loading diabetic shoe) size m',
#  'หลอดคอช่วยการหายใจ ชนิดทำด้วยพลาสติกtracheostomy tube cuffed  (กรมบัญชีกลาง)',
#  'edarbyclor',
#  'cica care',
#  'สายสวนสำหรับคล้องเกี่ยว (snare catheter)',
#  'lanoxin',
#  'leucoplus',
#  'ลิ้นหัวใจเทียมชนิดเนื้อเยื่อทำจากวัว c-e perimount mitral valve no.',
#  'asahi ptca guide wire',
#  'fungazol',
#  'สายสวนหลอดเลือดเพื่อการวินิจฉัย (vascular diagnostic catheter) ทุกขนาด',
#  'intravenous disposable catheter ch.16',
#  'pradaxa',
#  'สกรูยึดแผ่นโลหะดามกระดูก cancellous screw thread',
#  'iodine tincture',
#  'ถุงมือผ่าตัด sterile ชนิดมีแป้งทำจากยางพาราเบอร์',
#  'agrenox',
#  're-สายตัดเลาะเนื้อเยื่อ needle knife triple lumen',
#  'differin',
#  'สายสวนหลอดเลือดนำทางเพื่อการรักษา (interventional vascular guiding catheter) jr',
#  'อาหารทางการแพทย์สำหรับผู้ป่วยภาวะวิกฤตที่ต้องการโปรตีนและพลังงานสูง กลิ่นวานิลลา neomune vanilla',
#  'madopar',
#  'lipofundin',
#  'visanne',
#  'stilnox',
#  'rectal tube',
#  'farmorubicin',
#  'aloxi',
#  'สายเครื่องกระตุกไฟฟ้าหัวใจอัตโนมัติ (implanle cardioverter-defibrillator lead) :6947m-62 cm',
#  'kanolone',
#  'cottoniod',
#  'สายสวนหลอดเลือดเพื่อตรวจโดยการฉีดสีชนิดแข็งพิเศษ guide wire',
#  'อุปกรณ์ประกอบเครื่อง cpap ท่อลมขนาดมาตรฐาน (standard air tubing), dia.',
#  'สายสวนเพื่อการขยายหลอดเลือดโคโรนารีด้วยบอลลูนชนิดติดใบมีด (cutting balloon catheter)',
#  'dialyzer ประสิทธิภาพสูง',
#  'เยื่อบุหัวใจทำจากวัว ผนังกั้นหัวใจเทียม (pericardium patch) (เวชภัณฑ์)',
#  'novoseven',
#  'cilosol',
#  'ethibon  ไม่มีเข็ม l',
#  'regpara',
#  'non-balloon replacement gastrostomy tube',
#  'flutaplex',
#  'valcyte',
#  'ชุดตรวจเชื้อไวรัส sars-cov-2 antigen ทางจมูก kestrel',
#  'daflon',
#  'สายสวนหลอดเลือดนำทางสำหรับการขยายหลอดเลือดแดงส่วนปลาย peripheral guiding (nr8.0-35-80-y-6s-vott)',
#  'accusol',
#  'activated clotting time (act) tubes',
#  'zinc acetate solution',
#  'jackson pratt round drain fr.10 (su',
#  'สายสวนเพื่อการขยายหลอดเลือดโคโรนารี่ด้วยขดลวดเคลือบยาต้านการตีบซ้ำชนิดโพลิเมอร์สลายตัวเองได้ size',
#  'dressing retention sheet size',
#  'ที่คลุมเข่า knee pad',
#  'duplo tip',
#  'glycopyrronium(mobinul)',
#  'อุปกรณ์พยุงข้อมือ m รอบข้อมือ',
#  'อุปกรณ์พยุงข้อมือหรือนิ้วthumb l/xl',
#  'สายสวนเพื่อการขยายหลอดเลือดโคโรนารีด้วยขดลวดเคลือบยาต้านการตีบซ้ำ biolimus a9tm -eluting stent system size',
#  'bk prosthesis endoskeletal (ขาเทียมระดับใต้เข่าแกนใน )',
#  'efamat',
#  'terumo guiding catheter jr',
#  'high fressure connecting tube (hpct-8.8-180-p-fm)',
#  'ลวดนำทางอุปกรณ์ต่างๆ เข้าสู่ท่อทางเดินปัสสาวะ ทำจาก nitinol เคลือบด้วยสาร ptfeขนาด',
#  'hibor',
#  'พลาสติกดามข้อเท้า foam / air walker m',
#  'librax',
#  'สายลวดนำสายสวนเพื่อการขยายหลอดเลือดแดงส่วนปลาย exchange angled glide rfspc-35-260',
#  'tecentriq',
#  'ปลอกหุ้มกล้องส่องตรวจทางเดินปัสสาวะ ขนาด',
#  'concor',
#  'แป้นปิดรอบลำไส้ proxima ขนาด',
#  'taxotere',
#  'ลวดนำทางสำหรับสายฉีดสี re-disposable guide wire',
#  'm.stomachica',
#  'ถุงน่องทำจากผ้ายืดแบบยาว no.xl (วัดรอบน่อง',
#  'insulatard hm penfill',
#  'temporary pacing wire เด็ก',
#  'synthetic absorbable polyglactin braided no.',
#  'cleanoze bottle',
#  'sebclair cream',
#  'เลนส์แก้วตาเทียมแบบนิ่มพับได้ชนิด (foldable iols) single piece รุ่น ct asphina',
#  'multiple perfusion ชนิด',
#  'picoprep',
#  'แผ่นโลหะไททาเนียมดามมุมกระดูกขากรรไกรขนาด(angle universla fracture plat)ขนาด',
#  'smofkabiven',
#  'สายสวนเพื่อการขยายหลอดเลือดแดงใหญ่เอออร์ต้าด้วยขดลวดหุ้มกราฟต์ (aortic stent graft) jotex e-tegra abdominal aortic stent graft',
#  'สายสวนหลอดเลือดการวินิจฉัย imager ii -sim2 fr.5 - .035 -',
#  'thiopental sodium',
#  'สายสวนเข้าหลอดเลือดดำส่วนกลางชนิดใส่ผ่านหลอดเลือดดำบริเวณคอหรือไหล่ ขนาด7fr,',
#  'ผ้ายืดพยุงสะโพก no. l รอบสะโพก',
#  'cettec',
#  'สายสวนเพื่อการขยายหลอดเลือดแดงส่วนปลายเลี้ยงไตตีบด้วยขดลวด แบบขยายโดยใช้บอลลูน',
#  'สายสวนเพื่อการขยายหลอดเลือดแดงส่วนปลายชนิดขดลวด self-expanding stent',
#  'guide wire stiff type',
#  'needle disposable dental size',
#  'สายสวนเพื่อการขยายหลอดเลือดโคโรนารี่ด้วยขดลวดเคลือบยาต้านการตีบซ้ำ (drug-eluting stent) synergy dia.3.0x12mm.',
#  'aodipine(aopine)',
#  'neometho',
#  'ultrasonic gel (ultrasound gel)',
#  'ผ้ายืดพยุงข้อเข่ามีแกนด้านข้างknee support m ความยาวรอบหัวเข่า',
#  'xigduo xr',
#  'แผ่นโลหะดามกระดูก ชนิดมีหัวสกรูพยุง (locking plate) lc-lcp',
#  'codepect',
#  'd-cyclone',
#  'diagno green',
#  'cavilon durable barrier cream',
#  'วงแหวน washers',
#  'ตะแกรงกรองลิ่มเลือดหลอดเลือดดำใหญ่ vena cava filter optease',
#  'ท่อช่วยหายใจendotracheal tube  with cuff (มี cuff)',
#  'prosure',
#  'zolam',
#  'ถุงน่องเส้นเลือดขอดรุ่นแรงรัดปกติความยาวถึงใต้เข่า l',
#  'actos',
#  'สายบอลลูนดึงนิ่ว balloon extractor triple lumen',
#  'ผ้าซับพับรวบเป็นก้อน (throat swab) ขนาดเล็กปราศจากเชื้อ (ขนาดบรรจุ',
#  'ท่อระบายช่องอก',
#  'เข็มเจาะตัดชิ้นเนื้อ semiauto.biop.with coxial',
#  'แผ่นโลหะดามกระดูก ชนิดมีหัวสกรูพยุง (locking plate) lat. distal fibula',
#  'neupro',
#  'ostenil',
#  'weck cell ชนิดมีก้าน, pva spears',
#  'podophyllum resin',
#  'atorvastatin(lipostat)',
#  'paracetamol',
#  'sitafloxacin(gracevit)50',
#  'dicloxacillin',
#  'lidocaine preservative free',
#  'อุปกรณ์ป้องกันการเสียดสีของกระดูกโคนนิ้วหัวแม่เท้างอก นิ้วเท้าชิดกัน',
#  'แผ่นโลหะดามกระดูก ชนิดมีหัวสกรูพยุง (locking plate) lcp superior anterior clavicle plate',
#  'สำลีแผ่น (cottonoid) ปราศจากเชื้อ size l ขนาด',
#  'effexor xr',
#  'ขดลวดปิดกั้นหลอดเลือด vortx-18 -fiber platinum coil',
#  'benzyl benzoate lotion',
#  'สายลวดนำสายสวนชนิดมีความยาวพิเศษ smooth guide angie .038-260',
#  'mercilon',
#  'jakavi',
#  'สายสวนเพื่อการขยายหลอดเลือดส่วนปลายด้วยขดลวด peripheral stent self - expandable size',
#  'xeloda',
#  'โลหะดามกระดูกสันหลัง ส่วนคอ (cervical locking plate) anterior cervical plate',
#  'niclosamide',
#  'เข็มเจาะตัดชิ้นเนื้อ qcs-18 -',
#  'busulfex .',
#  'albendazole(albemed)',
#  'เครื่องช่วยฟังสำหรับคนหูพิการแบบใส่ในช่องหู รุ่น muse',
#  'สายสวนเพื่อตรวจภายในหัวใจหรือหลอดเลือดด้วยการถ่ายภาพคลื่นเสียงสะท้อน(intravascular or intracardiac ultrasound) opticross-18 catheter+sled pullback',
#  'ตัวกรองไตเทียมแบบประสิทธิภาพสูง plasmaflo ( baxter )',
#  'แผ่นโลหะดามกระดูกชนิดเล็ก mini straight plate dia',
#  'chloroquine phosphate',
#  'etoricoxib(sandoz)',
#  'ข้อเข่าชนิดที่ส่วนรับน้ำหนักไม่สามารถเคลื่อนไหวได้ nexgen flex fix ไม่รวม patella',
#  'สายสวนหลอดเลือดอเนกประสงค์ (multipurpose catheter) ขนาดเล็กทุกขนาด',
#  'chalk-1.5',
#  'สายสวนผู้ชาย self cath(เวชภัณฑ์)',
#  'm.tussis',
#  'blendera mf',
#  'stocrin',
#  'yankauer suction handle pat-k82',
#  'repatha',
#  'สายสวนในท่อไต4 fr.x',
#  'folinic acid(folina)',
#  'esmeron',
#  'หลอดคอช่วยการหายใจชนิดปรับระยะได้ adjusle tracheostomy tube, portex adjusle flange tracheostomy, id',
#  'เข็มบอกตำแหน่ง breast localize double hook sinurep',
#  'synthetic nonabsorbable monofilament  ยาวไม่น้อยกว่า',
#  'deanxit',
#  'bonefos',
#  'สกรูยึดแผ่นโลหะดามกระดูก cancellous screw thread diameter',
#  'เฝือกพยุงระดับเอว l - s support no. l',
#  'pds*plus',
#  'efexor xr',
#  'อนุภาคอุดกั้นหลอดเลือด embosphere',
#  'utrogestan',
#  'แผ่นอิเล็กโทรดสำหรับกระตุกหัวใจ สำหรับผู้ใหญ่ ชนิดใช้แล้วทิ้ง ( zoll)',
#  'เครื่องช่วยฟังสำหรับคนหูพิการแบบกล่อง รุ่น concerto power',
#  'itraconazole',
#  'วัสดุใส่หนุนรับลูกตาเทียมชนิดไม่มีรูพรุน,ลูกแก้ว เบอร์',
#  'สายสวนเพื่อการขยายหลอดเลือดโคโรนารีด้วยขดลวดเคลือบยาต้านการตีบซ้ำ everolimus-eluting coronary stent system size',
#  'thymoglobulin',
#  'exopred eye drop',
#  'สายสวนหลอดเลือดขนาดเล็กและยาวพิเศษเพื่อการรักษา (interventional vascular microcatheter) quick-cross support catheter (all size)',
#  'omnipaque',
#  'เก้าอี้นั่งถ่ายพับได้ชนิดมีล้อ',
#  'แผ่นโลหะดามกระดูก ชนิดมีหัวสกรูพยุง (locking plate) lcp proximal femur plate',
#  'สายสวนหลอดเลือดเพื่อการวินิจฉัย (vascular diagnostic catheter) mariner braided sidewider',
#  'ribavirin',
#  'extension tube ความจุ',
#  'เครื่องช่วยฟังสำหรับคนหูพิการแบบทัดหลังใบหู ยี่ห้อ interton รุ่น ready2',
#  'เลนส์แก้วตาเทียมชนิดพับได้แก้ไขสายตาเอียง alcon รุ่น toric sn6at3-t9 , single piece, a-con',
#  'prenolol',
#  'silk',
#  'doxycycline',
#  'เครื่องช่วยฟังสำหรับคนหูพิการแบบทัดหลังใบหู รุ่น',
#  'irbesartan(besanta)',
#  'blue ribbon',
#  'เครื่องช่วยฟังสำหรับคนหูพิการแบบทัดหลังใบหู รุ่น hit pro',
#  'สายระบายน้ำดี neohydro fr',
#  'allevyn gentle border',
#  'ก๊าซสำหรับฉีดกดจอประสาทตา (intraocular gas) perfluoropropane (sf6)',
#  'carbamazepin(panitol)',
#  'xiliarx',
#  'immunokine',
#  'alcon sa60at',
#  'betaplast silver',
#  'ท่อช่วยหายใจendotracheal tube  มี cuff',
#  'ชุดยางรัดเส้นเลือดขอดในหลอดอาหาร ยางรัดเส้นเลือดขอดในหลอดอาหาร',
#  'เข็มเจาะแบบเวอร์เรส veress needle',
#  'เครื่องมือสำหรับ hemorrhoid ขนาด',
#  'diosmin',
#  'leukeran',
#  'kirschner wire with trocar tip',
#  'สายคล้องแขน arm sling (m)',
#  'synthetic absorbable antibacterial suture  ยาว70 cm. เข็ม j curve taperpoint',
#  'vimpat',
#  'unasyn',
#  'วัสดุเสริมความแข็งแรงทดแทนปล้องกระดูกหรือกระดูกสันหลังส่วนคอ/หน้าอก/หรือเอว (interbody fusion device : cage or peek) olif lumbar cage',
#  'ท่อต่อหลอดเลือดแดง femoral arterial cannulae no.',
#  'แผ่นโลหะดามกระดูก ชนิดมีหัวสกรูพยุง (locking plate) unilock reconsruction2.4 mm. angled',
#  'หลอดเลือดเทียมสำหรับการผ่าตัดหลอดเลือดส่วนปลาย ptfe vascular graft (ตามความยาวที่ใช้)',
#  'xultophy',
#  'สายลวดนำสายสวนเพื่อการขยายหลอดเลือดแดงส่วนปลาย lunderquist g/w ts-35-260-les',
#  'myocrisin',
#  'เลนส์แก้วตาเทียมชนิดพับได้ alcon รุ่น ma60ac , multipiece, a-con',
#  'calcit sg',
#  'laryngeal mask airway size',
#  'อาหารเสริมและโภชนบำบัด กลิ่นธัญพืช สูตรหวานน้อย ขนาด',
#  'calamine(gpo) lotion',
#  'spasium',
#  'vitalipid n adult',
#  'spo2 sensor neonatal for nellcor (disposable)',
#  'รถเข็นนั่งคนพิการอลูมิเนียม ขนาดใหญ่ถอดข้างได้ ขนาด',
#  'rituximab(redditux)',
#  'flexible reinforced endotracheal tube uncuffed',
#  'คีมหนีบหลอดเลือดโป่งพองในช่องกะโหลกศรีษะ std. aneurysm clip stright',
#  'madiplot',
#  'cpap ยี่ห้อ devilbiss รุ่น dv54d-hh',
#  'สายสวนเพื่อการขยายหลอดเลือดโคโรนารี่ด้วยขดลวดเคลือบยาต้านการตีบซ้ำ (drug-eluting stent) synergy dia.2.25x32mm.',
#  'ethilon',
#  'ถุงครอบหัวกล้องสำหรับชุดผ่าตัดผ่านกล้องระบบวีดีทัศน์: camera sleeve ขนาดเส้นผ่านศูนย์กลาง',
#  'chlorpromazine',
#  'methotrexate(alltrex)',
#  'เครื่องอัดอากาศขณะหายใจเข้าcpapชนิดแรงดันคงและแปรผลไม่มีเครื่องทำความชื้น',
#  'thyrogen  (2 vial)(เฉพาะ)',
#  'percutaneous endoscopic gastrostomy set (peg',
#  'barron corneal punch',
#  'laryngectomy tube no.',
#  'เครื่องช่วยฟังสำหรับคนหูพิการแบบทัดหลังใบหู รุ่น dp8',
#  'nystatin(tystatin)',
#  'vitamin b complex ed.',
#  'gas',
#  'สายสวนหลอดเลือดเพื่อการวินิจฉัยที่มีความลื่นมากเป็นพิเศษ glidecath cobra fr.',
#  'ถุงให้อาหารปั่น ขนาดความจุ',
#  'เลนส์แก้วตาเทียมชนิดนิ่มพับได้แบบมองเห็น',
#  'temporary pacing wire ผู้ใหญ่',
#  'virkon',
#  'thyrosit',
#  'biocalm',
#  'ชุดเช็ดตา แบบไม่มี eye pad',
#  'สายสวนเพื่อการขยายหลอดเลือดโคโรนารี่ด้วยขดลวดเคลือบยาต้านการตีบซ้ำ (drug-eluting stent) synergy dia.2.5x48mm.',
#  'ชุดเข็มฉีดยาระงับความรู้สึกที่ส่วนของเส้นประสาทโดยใช้กระแสไฟฟ้าเหนี่ยวนำ ชนิดให้ยาได้ต่อเนื่อง (peripheral nerve block continuous infusion catheter) ขนาด',
#  'dermalon',
#  'เฝือกพยุงระดับเอวback support no. s ขนาดรอบเอว',
#  'สมอยึดกระดูกเข้ากับเนื้อเยื่อ soft tissue fixation absorbable anchors twinfix ti',
#  'samsca',
#  'dermatome blade',
#  'non-absorbable suture(nylon)',
#  'สายสวนสำหรับคล้องเกี่ยว (snare catheter) indy otw vascular retriever (indy-8.0-35-100-40)',
#  'eucerin ultra white plus spotless night fluid',
#  'mefamed',
#  'ถุงเก็บปัสสาวะแบบติดหน้าขา (urine leg bag) ขนาด',
#  'ถุงน่องเส้นเลือดขอดแรงดันสูง',
#  'cutinova',
#  'อุปกรณ์ระบายน้ำในช่องสมองชนิดปรับแรงดันได้(programmable ventriculoperitoneal shunt)',
#  'targin',
#  'galvus',
#  'haloperidol',
#  'stomahesive w/flange #57mm(ฝาก',
#  'remdesivir',
#  'รถนั่งคนพิการชนิดพับได้ทำด้วยโลหะ ปรับไม่ได้ wheel chair รถเข็นคนไข้ พับได้ ถอดข้างได้ (ล้อใหญ่)',
#  'โลหะดามกระดูกสันหลัง ส่วนคอ (cervical locking plate) cervical plate',
#  'สมอยึดกระดูกเข้ากับเนื้อเยื่อ acu-pass',
#  'ค่าผสมยาเคมีบำบัดผู้ป่วยนอก (55825) - ห้องจ่ายยา',
#  'ข้อเข่าชนิดที่ส่วนรับน้ำหนักเคลื่อนไหวได้ lcs cemented ไม่รวม patella',
#  'เท้าเทียมแบบนิ้วแยก ( เบอร์',
#  "เข็ม bard 's bx (14gx10cm)",
#  'อุปกรณ์เครื่องจี้ปิดและตัดเส้นเลือด กรรไกรโค้ง harmonic ace',
#  'ไม้เท้า',
#  'ท่อต่อหลอดเลือดดำ femoral venous cannulae  (เวชภัณฑ์)',
#  'อุปกรณ์ระบายน้ำจากช่องสันหลัง thecoperitoneal shunt (เวชภัณฑ์)',
#  'invanz',
#  'coronary dilatation catheter size',
#  'สายสวนเพื่อการขยายหลอดเลือดโคโรนารี่ด้วยขดลวดเคลือบยาต้านการตีบซ้ำ (drug-eluting stent) synergy dia.3.0x32mm.',
#  'zyprexa',
#  'แผ่นโลหะดามกระดูก ชนิดมีหัวสกรูพยุง (locking plate) va-lcp two column distal radius',
#  'ขดลวดอุดกั้นหลอดเลือดชนิดปลดด้วยลวดผลักดัน nester mwce-18-14-8',
#  'ท่อช่วยหายใจendotracheal tube  มี cuff เวชภัณฑ์(บัตรทอง,ปกส.)',
#  'สายสวนหัวใจและหลอดเลือดเพื่อการวินิจฉัย (diagnosis catheter)',
#  'nitroglycerin spray',
#  'healon gv',
#  'hemolok l(non absorbable polymer ligating clips)(violet)',
#  'spironolactone(hyles)',
#  'xalacom eye drop',
#  'surgicel fibrillar',
#  'บอลลูนถ่างขยายทางเดินอาหาร esophageal balloon dilator with wire guide15-18',
#  'ตัวกรองไตเทียมประสิทธิภาพสูงพร้อมชุดสายยางนำเลือดสำหรับการทำ crrt พร้อมสายน้ำยาซิเตรทและแคลเซี่ยม citraset rca12',
#  'm.c.t. oil',
#  't-strap',
#  'ชุด chest drain',
#  'faslodex',
#  'vitalux plus',
#  'ตัวกรอง edwards hf',
#  'รถนั่งคนพิการชนิดพับได้ ปรับไม่ได้ wheel chair รถเข็นเจาะรู',
#  'แผ่นโลหะดามกระดูก ชนิดมีหัวสกรูพยุง (locking plate) unilock reconsruction2.4 mm.20holes',
#  'blade surgical  (ชนิดคาร์บอน)',
#  'allevyn gentle',
#  'neotica balm',
#  'scalp vein normal  (50ea/box)',
#  'poly-oph eye drop',
#  'foley catheter two ways ch.16 ballon',
#  'dicloxacillin(diclex)',
#  'ผ้าก๊อสพับ ปลอดเชื้อ ขนาด',
#  'ชุดสายสวนกระเพาะอาหารแบบใส่ผ่านกล้องส่องทางเดินอาหาร (percutaneous endoscopic gastrostomy) ขนาด',
#  'ตัวกรองไตเทียมสำหรับการกรอง plasma',
#  'อุปกรณ์พยุงข้อเข่ามีแกนด้านข้างpatella knee supprt xl',
#  'ชุด mask พ่นยา',
#  'ethibon polybutylate coated braided polyester,v-5',
#  'sirdalud',
#  'ชุดสายสวนเพื่อใช้รักษาเส้นเลือดขอดบริเวณขา ขนาด',
#  'intravenous disposable catheter ch.24 ชนิดคมและลื่นเป็นพิเศษ',
#  'verrumal solution',
#  'ptb brace',
#  'สายสวนเพื่อการการขยายหลอดเลือดโคโรนารีด้วยการดูดลิ่มเลือด aspiration catheter',
#  'ชุดเครื่องตัดและกรอกระดูกโดยใช้เครื่องความถี่สูง',
#  'n.s.s. eye solution',
#  'bilaxten',
#  'fenofibrate(adfen)',
#  'สายสวนชนิดสองช่องในท่อเดียว double lumen jugular',
#  'oliclinomel n7',
#  'dt vaccine',
#  'หมวกคลุมศรีษะปลอดเชื้อพร้อมเครื่องระบายอากาศ',
#  'a scabs',
#  'รถเข็นนั่งคนพิการอลูมิเนียมมาตรฐานขนาดเล็ก',
#  'etomidate-lipuro',
#  'nattear',
#  'pdsii',
#  'อุปกรณ์ประกอบเครื่อง cpap ท่อลมขนาดเล็ก (slim air tubing), dia.',
#  'digoxin(lanoxin)',
#  'ลวด sternotomy surgical suture with needle c-12-48 mm.',
#  'ถุงมือใช้แล้วทิ้ง ชนิดทำจากยางพารา เบอร์ m (50คู่/box)',
#  'เลนส์แก้วตาเทียมชนิดนิ่มพับได้โฟกัสเดียว (monofocal foldable intraocular lens) รุ่น sa60wf ชนิด single piece lens a-con',
#  'antacil gel',
#  'สายสวนนำเข้าหลอดเลือด introducer sheath kit a fr.5 - .035 -',
#  'cefuroxime',
#  'cleanoze bottle+ nasal powder',
#  'insulatard',
#  'amikacin',
#  'aredia',
#  'nerve stim. needle a50',
#  'septopal chain',
#  'แผ่นโลหะดามกระดูก ชนิดมีหัวสกรูพยุง (locking plate) lcp for distal femur,',
#  'central venous catheter size',
#  'remeron',
#  'ขวดปากกว้าง',
#  'สายล้างไต สายส่ง aqualine หรือ set crrt (acute)',
#  'สายสวนเพื่อการขยายหลอดเลือดแดงส่วนปลายด้วยบอลลูน(balloon dilatation catheter) (corail',
#  'ชุดอุปกรณ์สลายลิ่มเลือดภายในหลอดเลือดด้วยวิธีกลศาสตร์ (mechanical thrombectomy device) aspire max',
#  'เลนส์แก้วตาเทียมชนิดแข็งพับไม่ได้ rx รุ่น rohto re-06f , single piece, a-con',
#  'wheel walker size m (ที่ช่วยฝึกเดินแบบมีล้อขนาดกลาง)',
#  'ท่อช่วยหายใจendotracheal tube  uncuffed (ไม่มี cuff) (กรมบัญชีกลาง)',
#  'เครื่องกระตุกไฟฟ้าหัวใจอัตโนมัติ (single chamber aicd with rate responsive mri compatible) สามารถเข้าเครื่อง mri ได้ :evera mri dvmc3d4',
#  'flutiform',
#  'สายสวนเพื่อการขยายหลอดเลือดโคโรนารีด้วยขดลวดเคลือบยาต้านการตีบซ้ำ zotarolimus-eluting coronary stent system size',
#  'ซิลิโคนรักษาแผล topical silicone gel',
#  'คลิบหนีบเส้นเลือด ขนาดเล็ก(ligaclip small size lt',
#  'ท่อช่วยหายใจendotracheal tube  ไม่มี cuff เวชภัณฑ์(บัตรทอง,ปกส.)',
#  'ciprofloxacin',
#  'บอลลูนถ่างขยายทางเดินอาหาร esophageal balloon dilator with wire guide',
#  'สายสวนเพื่อการขยายหลอดเลือดโคโรนารี่ด้วยขดลวดเคลือบยาต้านการตีบซ้ำชนิดโลหะโคบอลต์โครเมียม แบบโพลิเมอร์ย่อยสลายเองได้ size',
#  'pregabalin(sandoz)',
#  'วัสดุสิ้นเปลืองในการผ่าตัดผ่านกล้อง ห่วงผูกเนื้อเยื่อชนิดละลายได้',
#  'สายสวนหลอดเลือดช่องท้อง pigtail fr.5 - .038 -',
#  'oxycontin',
#  'akynzeo',
#  'monofilment polyprolene mesh sheet (ตัดย่อยขนาด',
#  'cyramza',
#  'flexible reinforced endotracheal tube cuffed',
#  'teevir  (ปส.)',
#  'sulfin',
#  'ข้อตะโพกมีเบ้า(total hip prosthesis)รวมทั้งอุปกรณ์เสริม total hip camented',
#  'หลอดเลือดเทียมสำหรับการผ่าตัดหลอดเลือดแดงใหญ่แบบเส้นแยก vascular graft bifurcate diameter20x10 mm . length',
#  'ตัวกรองไตเทียม edwards hf',
#  'fluimucil a',
#  'ข้อตะโพกมีเบ้า(total hip prosthesis)รวมทั้งอุปกรณ์เสริม cementless / excia stem + ceramic head',
#  'bosentan(silkay)',
#  'ciclosporin a eye drop',
#  'ข้อศอกเทียม (total elbow arthroplasty) ( ไม่รวม allen plug )',
#  'central venous catheter double lumens',
#  'สายสวนหลอดเลือดนำทางสำหรับการขยายหลอดเลือดแดงส่วนปลาย marking pigtail',
#  'taflotan-s',
#  'metrolex',
#  'cabometyx',
#  'อุปกรณ์พยุงหัวเข่าขนิดเสริมแกนด้านข้างและปรับกระชับได้ sport adjusle knee silizer ขนาดรอบหัวเข่า',
#  'zovirax',
#  'ambisome',
#  'สายสวนหลอดเลือดเพื่อการวินิจฉัยที่มีความลื่นมากเป็นพิศษvertebral fr.4 - .038 -',
#  'lamivudine',
#  'สายสวนหัวใจและหลอดเลือดเพื่อการวินิจฉัย (diagnostic catheter) sizing catheter',
#  'gardenal sodium',
#  'suction closed system catheter ch.8',
#  'absorbable monofilament monocryl',
#  'พลาสติกดามข้อเท้า foam / air walker s',
#  'thioridazine(thiomed)',
#  'ใบมีดตัดกระจกตา (corneal trephine) radial vacuum trephine (for recipient) dia.7.0 mm.',
#  'alcon snd1t4',
#  'ลิ้นหัวใจเทียม c-e perimount aortic valve no.',
#  'สายสวนสำหรับคล้องเกี่ยว endovascular snare system micro',
#  'อุปกรณ์พยุงข้อเข่ามีแกนด้านข้างknee brace for her',
#  'สายสวนเพื่อการขยายหลอดเลือดแดงส่วนปลายด้วยบอลลูน',
#  'proscar',
#  'lusefi',
#  'ท่อนำสายสวนเข้าหลอดเลือด ( introducer sheath) ขนาดยาวพิเศษ',
#  'ขดลวดปิดกั้นหลอดเลือด nester mwce-',
#  'celebrex',
#  'ผนังหัวใจเทียมชนิดแผ่นสังเคราะห์ sterile bard ptfe felf silk',
#  'สายสวนชนิดสองช่องในท่อเดียว double lumen femoral',
#  'polyester tape non-sterile',
#  'คลิปหนีบเส้นเลือด ขนาดกลาง (ligaclip medium size clip lt',
#  'glibenclamide',
#  'metronidazole(mepagyl)',
#  'หลอดคอช่วยการหายใจชนิดทำด้วยพลาสติกมีลิ้นบังคับ cufless fenetrate tracheostomy tube , shiley',
#  'ข้อตะโพกมีเบ้า(total hip prosthesis)รวมทั้งอุปกรณ์เสริม c- stem + duraloc ( hybrid )',
#  'เลนส์แก้วตาเทียมชนิดพับได้แก้ไขสายตาเอียง alcon รุ่น toric sn6at7 , single piece, a-con',
#  'glanatec',
#  'สายคล้องนิ่วในท่อไตและไตชนิดก้นหอยทำจากวัสดุ nitinol ก้นหอยขนาด',
#  'กระบอกพลาสติกสำหรับดูดหรือให้ของเหลวลงสู่กระเพาะอาหารปราศจากเชื้อชนิดใช้ครั้งเดียว ขนาด',
#  'silver sulfadiazine cream',
#  'kanamycin',
#  'synthetic nonabsorbable monofilament -0 ยาว',
#  'neupogen',
#  'exocin',
#  'vicryl  heavy reverse cutting',
#  'tapcom-s eye drop',
#  'stopper red rubber',
#  'เครื่องช่วยฟังสำหรับคนหูพิการแบบทัดหลังใบหู รุ่น sensei',
#  'สายสวนหัวใจและหลอดเลือดเพื่อการวินิจฉัย catheter sim2 (510038sim2)',
#  'sodium chloride oral sol(200/)',
#  'synthetic absorbable polydioxanone suture /0 ยาว',
#  'urinometer set ต่อจากสายสวนระยะยาว(กรมบัญชีกลาง)',
#  'sofosbuvir(myhep)',
#  'alphagan-p',
#  'potassium chloride(potas)',
#  'อุปกรณ์พยุงข้อเท้าสำเร็จรูป elastic ankle support l',
#  'bis sensor',
#  'อาหารทางการแพทย์สูตรครบถ้วน ผสมใยอาหารหลายชนิดและ เอฟโอเอส กลิ่นวนิลา ขนาด',
#  'levophed',
#  'รถนั่งคนพิการชนิดพับได้ ปรับได้ wheel chaur รถเข็นปรับนอนได้',
#  'ขดลวดอุดกั้นหลอดเลือดชนิดปลดด้วยลวดผลักดัน vortx diamond -18-fiber platinum coil',
#  'paclitaxin',
#  'taflotan',
#  'mst',
#  'resolor',
#  'ขดลวดปิดกั้นหลอดเลือด (coils) mwce-35-14-6-nester',
#  'สกรูยึดแผ่นโลหะดามกระดูก',
#  'ข้อเข่าชนิดพิเศษเฉพาะบุคคล (revision tka) ข้อเข่าเทียมส่วนทิเบีย (tibial component)',
#  'novo pen',
#  'ranitidine(zantidon)',
#  'เข็มเจาะเลือดปลายนิ้ว ขนาด',
#  'อุปกรณ์พยุงข้อมือหรือนิ้ว thum support no. m',
#  'premarin',
#  'asmasal sdu',
#  'เครื่องช่วยการเต้นของหัวใจถาวรชนิดกระตุ้นหัวใจสองห้องต่อเนื่องกันปรับอัตราการเต้นอัตโนมัติ สามารถเข้าเครื่อง mri ได้ (dual chamber pacemaker with rate responsive mri compatible) :en1dr01',
#  'ข้อเข่าชนิดพิเศษเฉพาะบุคคล (revision tka) ก้านต่อของ tibial component',
#  'sebivo',
#  'ชุดข้อเทียมสำหรับการตัดส่วนกระดูกต้นขาส่วนล่าง',
#  'braid silk -0ยาวไม่น้อยกว่า',
#  'syringe insuline disposable',
#  'สายฉีดสีในท่อทางเดินปัสสาวะชนิด',
#  'loceryl nail laquer',
#  'cogentin',
#  'อุปกรณ์คลิบห้ามเลือดในระบบทางเดินอาหาร (hemoclip-role repositionable hemostasis clipping device)',
#  'nerve stim.needle a100',
#  'อุปกรณ์พยุงข้อศอกไม่มีแกนด้านข้างtennis elbow brace',
#  'nootropil',
#  'disposable s-type head & necks size',
#  'แปรงเก็บเซลล์ในท่อน้ำดีแบบมีลวดนำ cytology brush รุ่น bc-9c (เวชภัณฑ์)',
#  'blade knife skin graft',
#  'บอลลูนถ่างขยายทางเดินอาหาร biliary balloon dilater(',
#  'adult grounding pad c cord',
#  'แผ่นใยสังเคราะห์แทนผนังท้องชนิดเมมเบรน ความยาวไม่เกิน',
#  'ขาเทียมระดับใต้เข่าแกนในเท้าเทียมชนิดข้อเท้าโยกได้ (single axis)',
#  'dilantin',
#  'สายสวนเพื่อการขยายหลอดเลือดส่วนปลายด้วยขดลวดหุ้มกราฟต์ (peripheral stent graft) afx2 extension and vela (all size)',
#  'clopidogrel',
#  'สายสวนเพื่อการขยายหลอดเลือดแดงส่วนปลายด้วยขดลวดหุ้มกราฟต์ peripheral stent graft (begraft)',
#  'marcain',
#  'สายสวนนำเข้าหลอดเลือด introducer sheath',
#  'สายระบายน้ำดี skater fr',
#  'สายสวนเพื่อการขยายหลอดเลือดส่วนปลายด้วยขดลวด (peripheral stent) เคลือบยาต้านการตีบซ้ำ eluvia-drug eluting stent (all size)',
#  'สายสวนหลอดเลือดนำทางเพื่อการรักษา (interventional vascular guiding catheter) st01',
#  'เครื่องตรวจน้ำตาล accperforma',
#  'แป้นปิดรอบลำไส้ alterna แป้น',
#  'สายลวดนำสายสวนเพื่อการขยายหลอดเลือดแดงส่วนปลาย lunderquist g/w tsc-35-300-lesdc',
#  'ข้อเข่าชนิดที่ส่วนรับน้ำหนักไม่สามารถเคลื่อนไหวได้',
#  'orthopedic shoe (รองเท้าคนพิการขนาดใหญ่ )',
#  'ชุดอุปกรณ์สลายลิ่มเลือดภายในหลอดเลือดด้วยวิธีกลศาสตร์ (mechanical thrombectomy device) (all size)',
#  'dtp-hb- hib',
#  'ไหมเย็บแผล ชนิดเส้นเดี่ยว ไม่ละลายน้ำ ผลิตจากโพลีโพรไพลีน , ยาว',
#  'calcitonin(mycalcitonin)',
#  'oseni',
#  'ชุดตรวจเชื้อไวรัส sars-cov-2 antigen ทางจมูก baicare',
#  'dapsone',
#  'm-splint mสายคล้องแขนกันไหล่หลุด m',
#  'noxafil',
#  'ampicillin',
#  'caduet',
#  'oasis stent introduction oa -10 (10fr.)',
#  'peripheral stent self - expandable otw size',
#  'dipotassium phosphate',
#  'trivastal retard',
#  'water for',
#  'แผ่นปิดรักษาแผลเปื่อย ชนิดโฟม ต้านจุลชีพ mepilex border ag ขนาด',
#  'ชุดเครื่องตัดและกรอกระดูกโดยใช้เครื่องความถี่สูง reuse',
#  'phenylephrine',
#  'อุปกรณ์พยุงข้อเท้าสำเร็จรูป comfort lift ankle support l',
#  'teevir (sam)',
#  'เฝือกพยุงคอชนิดอ่อน soft collar no. l',
#  'สายลวดนำสายสวนเพื่อการขยายหลอดเลือดแดงส่วนปลาย roadrunner pc wire guide (rpc-35-180)',
#  'ตัวกรองไตเทียมแบบประสิทธิภาพสูง แยกพลาสมาชนิด hollow fiber พื้นที่ผิวไม่น้อยกว่า',
#  'famotidine(pepfamin)',
#  'ชุดยางรัดเส้นเลือดขอดในหลอดอาหาร ชุดยางรัดเส้นเลือด',
#  'rabies antiserum(erig)',
#  'voriconazole',
#  'gaviscon dual action',
#  'สายสวนเพื่อการขยายหลอดเลือดโคโรนารี่ด้วยขดลวด (coronary stent) coronary stent system size',
#  'ผ้าก๊อสพับ',
#  'clindamycin(clinda gpo)',
#  'ปอดเทียมผู้ใหญ่ (adult membrane oxygenator)',
#  'plastic afo size l (พลาสติกดามขาชนิดสั้นขนาดใหญ่กันเท้าตก)',
#  'synthetic absorbable ชนิดมียาฆ่าเชื้อ(anti-bacteria)',
#  'ข้อตะโพกไม่มีเบ้า austin moore hip prosthesis fenestrated standard stem head',
#  'syringe dispisable sterile',
#  'ชุดตรวจเชื้อไวรัส sars-cov-2 antigen ด้วยน้ำลาย (hip t01 biotech antegen detection kit)',
#  'flixotide evohaler',
#  'sanoskin melladerm plus',
#  'dm shoe (รองเท้าสำหรับผู้ป่วยเบาหวานแบบรัดส้นสองสาย)',
#  'ข้อเข่าชนิดที่ส่วนรับน้ำหนักเคลื่อนไหวได้ nexgen flex-mobile รวม patella',
#  'เข็มเจาะชิ้นเนื้อแบบกึ่งอัตโนมัติ (semi-auto biopsy needle) ขนาด 16160 multi-ram semiauto needle',
#  'amiparen',
#  'แผ่นโลหะดามกระดูก ชนิดมีหัวสกรูพยุง (locking plate) tomofix lateral tibial l /3 h',
#  'สายสวนเพื่อการขยายหลอดเลือดส่วนปลายด้วยบอลลูน (balloon dilatation catheter) ทนแรงดันน้อยกว่าเท่ากับ',
#  'ชุดยางรัดเส้นเลือดขอดในหลอดอาหาร ยางรัดเส้นเลือดขอดในหลอดอาหาร รุ่น mbl-u-6',
#  'probenecid(proben)',
#  'ถุงเก็บสิ่งขับถ่ายจากลำไส้ ชนิดใช้แล้วทิ้ง colostomy bag',
#  'opsumit',
#  'depakine',
#  'benzydamine(d-throat)',
#  'simoyiam',
#  'สายคล้องแขน arm sling no. m วัดความยาวแขนท่อนล่างจากปลายนิ้วก้อยถึงข้อศอก',
#  'purinetone',
#  'เลนส์แก้วตาเทียมชนิดพับได้ alcon รุ่น sa60at , single piece,a-con',
#  'ethibond excel  with trocar',
#  'ปรอทวัดไข้ทางทวารหนัก',
#  'เข็มตัดชิ้นเนื้อ qcs-18 -',
#  'sucrate gel',
#  'ชุดอุปกรณ์สำหรับจี้ทำลายเนื้องอกด้วยคลื่นความถี่วิทยุ ความยาว',
#  'chlordiazepoxide',
#  'advagraf',
#  'เลนส์แก้วตาเทียม ชนิดพับได้แบบมองไกลระยะเดียวพร้อมแก้ไขสายตาเอียง ชนิด tecnis toric',
#  'ลิ้นหัวใจเทียมชนิดเนื้อเยื่อทำจากวัว trifecta aortic valve no.',
#  'ชุดถ้วยผสม bone cement ระบบสูญญากาศ',
#  'เฝือกพยุงระดับเอว back support no. l',
#  'balloon extractor triple lumen',
#  'sulbactam(sibatam)',
#  'ท่อระบายน้ำดีชนิดพลาสติก pigtail',
#  'แผ่นโลหะสำหรับยึดกะโหลกศีรษะ (titanium plate) ชนิดกลม cranioplasty plate, mid burr hole plate',
#  'gpo-vir z',
#  'terumo guide wire',
#  'ข้อตะโพกมีเบ้า(total hip prosthesis top)รวมทั้งอุปกรณ์เสริม total hip cementless',
#  'อุปกรณ์หยุดเลือดที่ radial artery tr-band',
#  'ors powder',
#  'สายสวนหลอดเลือดขนาดเล็กและยาวพิเศษเพื่อการรักษา (interventional vascular microcatheter) rubicon support catheter',
#  'elidel',
#  'เครื่องช่วยฟังสำหรับคนหูพิการแบบใส่ในช่องหู รุ่น aries plus series (cic,itc,ite)',
#  'ผ้ายืดพยุงข้อเข่าelastic knee support s',
#  'dexamethasone np eye drop',
#  'ท่อช่วยหายใจendotracheal tube  with cuff (มี cuff) (กรมบัญชีกลาง)',
#  'เฝือกพยุงคอชนิดอ่อน soft collar no. l วัดรอบคอ',
#  'terumo guiding catheter al-2',
#  'โลหะดามกระดูกและใส่โพรงกระดูก ชนิดแยกชิ้น gamma lag screw',
#  'aerius',
#  'micronebulizer อย่างเดียว',
#  'สายลวดนำสายสวนขนาดเล็กพิเศษ (fathom -',
#  'รถนั่งคนพิการชนิดพับได้ทำด้วยโลหะ ปรับไม่ได้ wheel chair รถเข็น ชนิดพับได้ ถอดข้างได้',
#  'boost fiber',
#  'ท่อใส่เข้าท้องชนิดฟอกเลือดแทนไตแบบถาวร ชนิดก้นหอย tenckhoff ชนิดก้นหอย (acute) - [ucs/sss]',
#  'สายสวนเพื่อการขยายหลอดเลือดโคโรนารี่ด้วยขดลวดเคลือบยาต้านการตีบซ้ำ (drug-eluting stent) synergy dia.3.0x28mm.',
#  'สายสวนหลอดเลือดเพื่อนำทางสำหรับการขยายหลอดเลือดแดงส่วนปลาย guider softip fr.5-.053 -',
#  'หลอดเลือดเทียมสำหรับการผ่าตัดหลอดเลือดส่วนปลาย ptfe vascular graft (ตามความยาวที่ใช้ cm)',
#  't-tube',
#  'risperidone gpo',
#  'vastarel mr',
#  'สายสวนปัสสาวะชนิดในท่อไต ureteric cath',
#  'amitiza',
#  'boost optimum',
#  'spectra optia collection set',
#  'agrylin',
#  'darzalex sc',
#  'miostat',
#  'chlorpheniramine(cpn)',
#  'เลนส์แก้วตาเทียมชนิดพับได้ sensar รุ่น aaboo, one piece, a-con',
#  'dermatome blade (electric)',
#  'extremity drape ขนาด',
#  'methergin',
#  'สายสวนหลอดเลือดฉีดสีหลอดเลือดโคโรนารี catheter cobra (hnbr5.0-35-65-p-ns-c2)',
#  'alphagan',
#  's.m. oto ear drop',
#  'ผ้ายืดปิดแผลชนิดมีกาวในตัว (elastic cohesive retention bandage) ขนาด',
#  'diprotop',
#  'แผ่นโลหะดามกระดูกชนิดแคบ narrow lc-dcp',
#  'ค่าผสมยาเคมีบำบัดผู้ป่วยใน(55825) - ห้องยา',
#  'สายสวนหลอดเลือดฉีดสีหลอดเลือดหัวใจโคโรนารี angiographic catheter size pig ,',
#  'ganfort pf eye drop',
#  'spasmex',
#  'silver nitrate',
#  'ชุดอุปกรณ์สำหรับจี้ทำลายเนื้องอกด้วยคลื่นความถี่วิทยุ (radiofrequency ablation set) ; leveen needle electrode with grounding pad รุ่น co-access ขนาด',
#  'ไฮโดรเจลผสมซิลเวอร์ ขนาด',
#  'doxorubicin(adrim)',
#  'โลหะดามกระดูกและใส่ในโพรงกระดูกข้อตะโพกชนิดมีเกลียว dhs plate',
#  'urgo tul',
#  'aethoxysklerol',
#  'zavedos',
#  'benserazide+ levodopa(vopar)',
#  'verorab rabies vaccine',
#  'วัสดุสำหรับอุดกั้นหลอดเลือดขนาดใหญ่ชนิดก้อน vascular plug size',
#  'hymed',
#  'แผ่นประคบ ร้อน-เย็น cold - hot pack ขนาดใหญ่',
#  'omeprazole(zefxon)',
#  'innohep',
#  'medroxyprogesterone',
#  'สายสวนและอุปกรณ์เพื่อการขยายลิ้นหัวใจด้วยบอลลูนธรรมดา (vulvuloplasty balloon ) size',
#  'atropine',
#  'kenalyn shampoo',
#  'levonorgestrel(madonna)',
#  'remicade',
#  'สายสวนนำเข้าหลอดเลือด introducer sheath (pro-8f-11-035+needle)',
#  'เครื่องช่วยการเต้นของหัวใจถาวรชนิดกระตุ้นหัวใจสองห้องต่อเนื่องกัน ปรับอัตราการเต้นอัตโนมัติ รุ่น',
#  'terbutaline',
#  'prezcobix',
#  'อุปกรณ์เครื่องจี้ปิดและตัดเส้นเลือด กรรไกรโค้ง',
#  'loxonin',
#  'ผ้าอ้อมผู้ใหญ่ สำเร็จรูปชนิดกางเกง ขนาด xl บรรจุ',
#  'โลหะดามใส่ในโพรงกระดูกชนิดมีรูล็อคสำหรับยึดกระดูกส่วนกลางและสลักยึดกระดูก tibia',
#  'symbicort',
#  'venofer',
#  'protopic oint',
#  'skin staple sterile',
#  'lastet',
#  'หัวจี้ชนิดโมโนโพล่าหรือไบโพล่า',
#  'โลหะดามกระดูกและใส่ในโพรงกระดูกชนิดไม่มีเกลียวรวมสกรู angle blade plate',
#  'adenocor',
#  'dramamine',
#  'strattera',
#  'พลาสติกดามข้อเท้า airsport ankle brace s, lt',
#  'ข้อเข่าชนิดที่ส่วนรับน้ำหนักไม่สามารถเคลื่อนไหวได้ genesis ii p/s รวม patella',
#  'rifam',
#  'nebulizer-mouth pice and mask',
#  'สายสวนหลอดเลือดเพื่อนำทางสำหรับการขยายหลอดเลือดแดงส่วนปลาย guider softip fr.8 -.086 -',
#  'connector for two drain',
#  'salagen',
#  'd',
#  'วัสดุฉีดอุดกั้นหลอดเลือดชนิดเหลวแบบแข็งตัวเร็ว histoacryl blue tissue adhesive(กาวทางการแพทย์)',
#  're-harmonic focus blade,',
#  'loperamide',
#  'อุปกรณ์ประกอบเครื่อง cpap หน้ากากครอบจมูก ทำจากซิลิโคนและเจล พร้อมสายรัดศีรษะ',
#  'ethicon monofilament polyamide',
#  ...}

# %%
# Remove the dose from values in the drugdigits list
cleaned_drugdigits = []
for value in drugdigits:
    cleaned_val = re.sub(r'(\s+\d+\s*mg|\s+\d+\s*%|inj\.?|tab\.?|\[.*?\]|\(.*?\)|\s+450\s*ml|0\.2ml)', '', value)
    cleaned_drugdigits.append(cleaned_val)

set(cleaned_drugdigits)
# Out:
# {'2% chlorhexidine in alcohol',
#  '3tc  ',
#  '3tc lamivudine ',
#  '3tc suspension  ',
#  '5-fu/  for subconjunctival'}

# %%
clean = pd.DataFrame(drugdigits).shape
clean
# Out:
# (11907, 1)

# %%
genericCol3 = []
for i in genericCol2:
    for word in words_to_remove:
        i = i.replace(word, "")
    i = re.sub(r'\bno\.\d+(\.\d+)?\b|\s+450\s*ml|\b0\.2\b|\b500\b', '', i)
    genericCol3.append(i.strip())

# Print the updated lists
#print("Updated drugCol3:", drugCol3)
#print("Updated genericCol3:", genericCol3)

# %%
set(genericCol3)
# Out:
# {'amikacin(gpo)',
#  'adacel vaccine',
#  'vehicle for omeprazole',
#  'poro supp',
#  'carboplatin(kemocarb)',
#  'herceptin infusion',
#  'synvisc',
#  'bioflor',
#  'methylprednisolone',
#  'midorine',
#  'nimbex powd for',
#  'risperdal oral soln',
#  'vocinti',
#  'cresemba',
#  'genteal eye drops',
#  'sandostatin lar powd for',
#  'cardiprin',
#  'azithromycin(zithrotel)',
#  'cinacalcet(calcelar)',
#  'nevanac ophth susp',
#  'vesicare film-coated',
#  'lipitor',
#  'duoderm gel',
#  'profilnine sd powd for',
#  'metoprolol',
#  'uromitexan',
#  'viartril-s',
#  'ephedrine gpo',
#  'cidofovir(emcure)',
#  'celvista film-coated',
#  'multivitamin drop',
#  'adalat cr',
#  'hyruan one',
#  'clonazepam(prenapil)',
#  'sandimmun neoral solution',
#  'milk of magnesia(gpo) suspension',
#  'ivig',
#  'cyclo progynova',
#  'solu-cortef powd for',
#  'proctosedyl rectal oint',
#  'efavirenz(gpo)',
#  'hydrogen peroxide sahakarn topical soln',
#  'peg-intron powd for',
#  'mevac-a',
#  'hbig(hepatitis b ig)',
#  'xalatan eye drops',
#  'fresofol',
#  'glycerin enema',
#  'caraten',
#  'diphereline p.r. powd for',
#  'differin topical gel',
#  'selbex',
#  'mapenem powd for',
#  'zyvox infusion',
#  'voltaren',
#  'tolvon',
#  'bicalutamide',
#  'triumeq',
#  'd2',
#  'regaine topical soln',
#  'n.s.s.irrigate',
#  'multivitamin',
#  'cravit ophthalmic ophth soln',
#  'plendil xr',
#  'tetanus antitoxin b.p. vaccine',
#  'faverin film-coated',
#  'orkelax',
#  'viread film-coated',
#  'docetaxel hospira',
#  'hidrasec paediatric',
#  'omeprazole(gpo)',
#  'vesanoid',
#  'azopt ophth susp',
#  'nifedipin t20 stada retard modified-release',
#  'novorapid penfill',
#  'thalidomide(thado)',
#  'doperan susp',
#  'benzac ac',
#  'neotica balm cream',
#  'betamethasone(gpo) cream',
#  'cold cream (heb)',
#  'sat.ki. solution',
#  'zepatier',
#  'favipiravir',
#  'chlorpheniramine gpo',
#  'arixtra',
#  'tebonin forte',
#  'xanthium',
#  'olumiant',
#  'verrumal topical soln',
#  'hirsuit hair tonic spray',
#  'aethoxysklerol',
#  'mamofen',
#  'actrapid hm',
#  'lotemax',
#  'expogin',
#  'mezavant xl',
#  'precedex infusion',
#  'tidar',
#  'renvela',
#  'k.k. balm',
#  'livact granules',
#  'depakine powd for',
#  'trileptal film-coated',
#  'revolade film-coated',
#  'inlyta',
#  'influenza vaccine(vaxigrip tetra)',
#  'gpo-a-flu',
#  'tractocile',
#  'sixime',
#  'unison enema solution',
#  'dynastat powd for',
#  'vincristine pharmacia',
#  'videx ec enteric-coated',
#  'diprotop oint',
#  'zometa',
#  'diabederm cream',
#  'encephabol coated',
#  'navelbine soft',
#  'zytiga',
#  'propyl',
#  'sodium bicarbonate',
#  'phenobarbitone',
#  'mirena intra-uterine system',
#  'neotigason',
#  'erythomycin',
#  'zyno cream',
#  'sulfasalazine(salazine)',
#  'avelox film-coated',
#  'zalain',
#  'd-10-s',
#  'clenil aerosol spray',
#  'mircera',
#  'abacavir/lamivudine(mylan)',
#  'diamicron mr modified-release',
#  'victoza',
#  'reyataz',
#  'd-5-1/4 s',
#  'miostat ophth soln',
#  'andriol testos',
#  'sho',
#  'minirin (ddavp)',
#  'midazolam hexal',
#  'alkeran',
#  'dimenhydrinate gpo',
#  'fulvestrant(sandoz)',
#  'indomethacin',
#  'vivacor',
#  'puroxan',
#  'gpo-vir t',
#  'glucose powder',
#  'glucobay',
#  'rifampicin',
#  'oxitan',
#  'samnir',
#  'zithromax powd for',
#  'notrixum',
#  'avodart',
#  'edarbyclor',
#  'methadone gpo',
#  'lanoxin',
#  'fungazol',
#  'pradaxa',
#  'valdoxan film-coated',
#  'myonal sugar-coated',
#  'agrenox',
#  'ufur',
#  'madopar',
#  'lipofundin',
#  'visanne',
#  'stilnox',
#  'farmorubicin',
#  'aloxi',
#  'kanolone',
#  'cilosol',
#  'regpara',
#  'isoptin sr sr',
#  'daflon',
#  'accusol',
#  'zinc acetate solution',
#  'glycopyrronium(mobinul)',
#  'noxafil oral susp',
#  'efamat',
#  'hibor',
#  'comtan film-coated',
#  'tecentriq',
#  'concor',
#  'invanz powd for',
#  'taxotere',
#  'penicillin v asian union',
#  'vermine coated',
#  'picoprep',
#  'smofkabiven',
#  'succinyl',
#  'singulair chewable',
#  'cettec',
#  'alum gel oral susp',
#  'filgen',
#  'neometho',
#  'gracevit film-coated',
#  'xigduo xr',
#  'd-cyclone',
#  'diagno green',
#  'zolam',
#  'actos',
#  'neupro',
#  'ostenil',
#  'lamivudine mylan film-coated',
#  'podophyllum resin',
#  'atorvastatin(lipostat)',
#  'paracetamol',
#  'dicloxacillin',
#  'lidocaine preservative free',
#  'actrapid penfill',
#  'gasmotin film-coated',
#  'benzyl benzoate lotion',
#  'mercilon',
#  'jakavi',
#  'niclosamide',
#  'albendazole(albemed)',
#  'ebixa film-coated',
#  'chloroquine phosphate',
#  'etoricoxib(sandoz)',
#  'stocrin',
#  'repatha',
#  'folinic acid(folina)',
#  'acetin powd for oral soln',
#  'deanxit',
#  'bonefos',
#  'xylocaine topical jelly',
#  'efexor xr',
#  'veragel-dms',
#  'immunokine infusion',
#  'utrogestan',
#  'thymoglobulin',
#  'exopred eye drop',
#  'ribavirin',
#  'prenolol',
#  'natacyn ophth susp',
#  'neulastim pre-filled',
#  'levemir flexpen pre-filled pen',
#  'doxycycline',
#  'irbesartan(besanta)',
#  'xiliarx',
#  'iressa film-coated',
#  'miacalcic nasal spray',
#  'diosmin',
#  'prednisil cream',
#  'baraclude film-coated',
#  'dosanac gel emulgel',
#  'leukeran',
#  'fluomizin vag',
#  'norvir soft-gelatin',
#  'vimpat',
#  'unasyn',
#  'xultophy',
#  'myocrisin',
#  'f ophth susp',
#  'calamine(gpo) lotion',
#  'calciferol bd',
#  'cycloserine meiji',
#  'vitalipid n adult',
#  'rituximab(redditux)',
#  'madiplot',
#  'voluven infusion',
#  'gardenal powd for',
#  'exelon patch dermal patch',
#  'methotrexate(alltrex)',
#  'nystatin(tystatin)',
#  'vitamin b complex ed.',
#  'gas',
#  'chlorpromazine gpo',
#  'kamrab',
#  'thyrosit',
#  'biocalm',
#  'neoamiyu infusion',
#  'samsca',
#  'mefamed',
#  'gemzar infusion',
#  'galvus',
#  'targin',
#  'haloperidol',
#  'remdesivir',
#  'nurofen',
#  'lanzaar',
#  'bio-tt vaccine',
#  'm.c.t. oil',
#  'elomet cream',
#  'eurofer-iron oral liqd',
#  'hycamtin infusion',
#  'poly-oph eye drop',
#  'acetar infusion',
#  'sirdalud',
#  'duac once daily topical gel',
#  'n.s.s. eye solution',
#  'bilaxten',
#  'fenofibrate(adfen)',
#  'oliclinomel n7',
#  'dt vaccine',
#  'a scabs',
#  'etomidate-lipuro',
#  'cefuroxime',
#  'salofalk enteric-coated',
#  'insulatard',
#  'amikacin',
#  'tracleer film-coated',
#  'cetaphil gentle skin cleanser lotion',
#  'flutiform',
#  'gynoflor vag',
#  'novoseven susp for',
#  'lipiodol ultra-fluide',
#  'pregabalin(sandoz)',
#  'albutein infusion',
#  'oxycontin',
#  'akynzeo',
#  'cyramza',
#  'teevir  (ปส.)',
#  'sulfin',
#  'fluimucil a',
#  'bosentan(silkay)',
#  'ciclosporin a eye drop',
#  'h-peran',
#  'taflotan-s',
#  'metrolex',
#  'cabometyx',
#  'seroxat film-coated',
#  'lamivudine',
#  'crestor film-coated',
#  'proscar',
#  'lusefi',
#  'celebrex',
#  'metronidazole(mepagyl)',
#  'glanatec',
#  'kanamycin',
#  'prolia pre-filled syringe',
#  'tapcom-s eye drop',
#  'sodium chloride oral sol(200/)',
#  'enbrel pre-filled',
#  'sofosbuvir(myhep)',
#  'potassium chloride(potas)',
#  'levophed',
#  'paclitaxin',
#  'rothricin film-coated',
#  'taflotan',
#  'resolor',
#  'salagen film-coated',
#  'premarin',
#  'vislube eye drops',
#  'nelapine',
#  'ofloxin film-coated',
#  'cogentin',
#  'nootropil',
#  'casodex film-coated',
#  'vancin-s powd for',
#  'dilantin',
#  'clopidogrel',
#  'marcain',
#  'dtp-hb- hib',
#  'calcitonin(mycalcitonin)',
#  'oseni',
#  'dianeal pd-2 peritoneal dialysis solution with',
#  'ampicillin',
#  'noxafil',
#  'caduet',
#  'dipotassium phosphate',
#  'trivastal retard',
#  'water for',
#  'phenylephrine',
#  'fluimucil infusion',
#  'nizoral cream',
#  'teevir (sam)',
#  'silvex cream',
#  'famotidine(pepfamin)',
#  'rabies antiserum(erig)',
#  'voriconazole',
#  'gaviscon dual action',
#  'clindamycin(clinda gpo)',
#  'flixotide evohaler',
#  'virkon topical powd',
#  'amitryptyline gpo',
#  'probenecid(proben)',
#  'opsumit',
#  'benzydamine(d-throat)',
#  'simoyiam',
#  'daivonex oint',
#  'matcine',
#  'purinetone',
#  'sucrate gel',
#  'advagraf',
#  'chloroph eye drops',
#  'sulbactam(sibatam)',
#  'ors powder',
#  'glucose atlantic soln for',
#  'dexamethasone np eye drop',
#  'anxira',
#  'aerius',
#  'maril',
#  'cef-4 powd for',
#  'risperidone gpo',
#  'vastarel mr',
#  'amitiza',
#  'optive eye drops',
#  'darzalex sc',
#  'agrylin',
#  'chlorpheniramine(cpn)',
#  'ifluorescein(ศิริราช)',
#  'systane ultra (ud) eye drops',
#  'relestat ophth soln',
#  'mitomycin-c kyowa',
#  'spasmex',
#  'ganfort pf eye drop',
#  'silver nitrate',
#  'zavedos',
#  'doxorubicin(adrim)',
#  'benserazide+ levodopa(vopar)',
#  'cefamezin powd for',
#  'sia-mox',
#  'leunase infusion',
#  'omeprazole(zefxon)',
#  'innohep',
#  'medroxyprogesterone',
#  'kenalyn shampoo',
#  'levonorgestrel(madonna)',
#  'prezcobix',
#  'eposin',
#  'loxonin',
#  'symbicort',
#  'venofer',
#  'protopic oint',
#  'lastet',
#  'durogesic transdermal patch',
#  'adenocor',
#  'dramamine',
#  'strattera',
#  'rifam',
#  'avexa infusion',
#  'd',
#  'aquagel',
#  'spectraban',
#  'exelon tts',
#  'sildenafil(gpo)',
#  'mydriacyl ophth soln',
#  'simbrinza eye drop',
#  'herceptin subcutaneous',
#  'pneumo',
#  'neostigmine(chi sheng)',
#  'lopinavir/ritonavir(gpo)',
#  'iruxol mono oint',
#  'fucithalmic eye drops',
#  'ossobon-d',
#  'hydrochlorothiazide',
#  'defungo vag cream',
#  'premarin vag cream',
#  'relvar',
#  'florinef',
#  'co-trimoxazole suspension',
#  'navelbine',
#  'mel-od',
#  'aldara cream',
#  'insulatard penfill',
#  'mecylic(betamethasone+salicylic) oint',
#  'ct',
#  'valsartan(tareg)',
#  'solcoseryl eye gel',
#  'rupafin',
#  'varilrix vaccine',
#  'streptomycin sulfate m&h',
#  'cifloxin film-coated',
#  'systane ultra eye drops',
#  'lasix',
#  'cancidas infusion',
#  'arimidex',
#  'sodium chloride',
#  'pegasys',
#  'livial',
#  'cuprimine',
#  'kocitaf',
#  'dulcolax adult supp',
#  'jadelle',
#  'depakine chrono cr',
#  'chirocaine  soln',
#  'marcain polyamp',
#  'providone iodine sol.10%',
#  'melox',
#  'frisium',
#  'tygacil infusion',
#  'avigan',
#  'd4t stavudine',
#  'elomet lotion',
#  'thyrogen powd for',
#  'alcohol (myseptic mybacin) gel',
#  'nimbex',
#  'cholestyramina powder',
#  'provera',
#  'atorvastatin(xarator)',
#  'desirel',
#  'opalmon',
#  'spasuri',
#  'uritos',
#  'lotio p. n0.1',
#  'a.d. mycin',
#  'nuvigil',
#  'ketoconazole(sporaxyl)',
#  'cleanoze nasal powder',
#  'azyter',
#  'vigamox eye drops',
#  'herzuma',
#  'vitalux plus coated time-release',
#  'atropine sulfate demo',
#  'zerbaxa',
#  'lumigan ophth soln',
#  'rotavirus(rotateq) vaccine',
#  'stomahesive powder',
#  'effcil',
#  'inh',
#  'daxas fc',
#  'amaryl',
#  'servitrocin film-coated',
#  'cesoline-w film-coated',
#  'speeda vaccine  (sam)',
#  'siadocin',
#  'alcohol',
#  'sofosbuvir+velpatasvir (myhep all)',
#  'mevalotin protect',
#  'utmos',
#  'unisia',
#  'mydria mac eye drop',
#  'vitara clinda',
#  'magnesium sulphate atlantic',
#  'cardepine infusion',
#  'nasonex aqueous nasal spray',
#  'vitara aha',
#  'glyceol',
#  'obucort swinghaler',
#  'zemiglo',
#  'dexasone',
#  'diphereline',
#  'mist. scill ammon. gpo syr',
#  'fucidin ointment',
#  'casodex',
#  'physiogel moisture therapy cream',
#  'depakine oral soln',
#  'vinblastin',
#  'dermovate',
#  'kabiven pl',
#  'carbapin',
#  'lanoxin pg',
#  'predsomed',
#  'gpo thc cannabis oil drops',
#  'dormicum',
#  'aminoven infant',
#  'bacin iv',
#  'noxidil',
#  'zoladex la safesystem depot',
#  'grisovin-fp',
#  'montelukast(astair)',
#  'levetiracetam(millitam)',
#  'legalon',
#  'd-10-w',
#  'loceryl nail lacquer',
#  'ambisome infusion',
#  'xtandi',
#  'halox syr',
#  'teno-em',
#  'ril',
#  'midazolam',
#  'diclofenac(fenac)',
#  'viion',
#  '3tc 150',
#  'h.b.vaccine',
#  'librax sugar-coated',
#  'ddi',
#  'ozempic',
#  'diprospan',
#  'pontevia',
#  'montek',
#  'trental',
#  'tagrisso',
#  'stivarga',
#  'gpo-l-one',
#  'aclasta',
#  'diovan',
#  'lasix high dose',
#  'nutriflex lipid vr',
#  'duphalac',
#  'clinott',
#  'isosorbide mononitrate(monolin)',
#  'campto',
#  'carbosin',
#  'diclofenac',
#  'haldol decanoas',
#  'dopsan',
#  'ts-one',
#  'vitamin b',
#  'atazanavir',
#  'dozozin',
#  'dbl sodium nitroprusside vial',
#  'imfinzi',
#  'bleocin',
#  'tasigna',
#  'anta',
#  'latuda',
#  'boostagen',
#  'alphagan ophth soln',
#  'prostagutt',
#  'aricept film-coated',
#  'zyrtec film-coated',
#  'donepezil(alzime)',
#  'noxidil forte',
#  'nurofen fc let',
#  'levetiracetam(focale)',
#  'cellufresh',
#  'minapine sugar-coated',
#  'd-50-w',
#  'anthelios xl spf50 fluid',
#  'sirturo',
#  'nevirapine(neravir)',
#  'normal saline',
#  'vitamin b2 ssp',
#  'mst continus',
#  'favipiravir(fabiflu)',
#  'endoxan coated',
#  'besmal',
#  'defungo vag',
#  'benpine',
#  'vilerm cream',
#  'pletaal sr',
#  'ea cream',
#  'tasigna hard',
#  'siamformet film-coated',
#  'trusopt',
#  'iodine gargle sh',
#  'olopa mac',
#  'sterile water',
#  'pulmicort respules',
#  'gpo-vir z250',
#  'ultravist',
#  'd-5-1/3 s',
#  'rifam film-coated',
#  'dolutegravir(mylan)',
#  'tonizep',
#  'pred-forte eye drops',
#  'rhinocort aqua nasal spray',
#  'mist tussis oral susp',
#  'kamillosan-m spray oromucosal spray',
#  'mecobalamin-daito',
#  'sodium chloride powder',
#  'salofalk supp',
#  'alimta infusion',
#  'epsitron',
#  'activated charcoal',
#  'xenetix',
#  'herceptin',
#  'nornal saline eye drop',
#  'forxiga',
#  'furoxime film-coated',
#  'protaxos granules for oral susp',
#  'atorvastatin sandoz',
#  'proctosedyl supp',
#  'foster mdi',
#  'quinine sulfate',
#  'pms-pantoprazole powd for',
#  'gentamicin',
#  'revatio film-coated',
#  'mabthera infusion',
#  'erbitux infusion',
#  'magnesia',
#  'kapanol',
#  'edicin infusion',
#  'isotrex topical gel',
#  'duotrav bak-free ophth soln',
#  'tracrium',
#  'darzalex',
#  'difflam forte throat spray',
#  'cisatracurium(kabi)',
#  'orthonase',
#  'ursofalk',
#  'azt',
#  'dewax ear drops',
#  'buchu co mixture',
#  'savlon',
#  'urea',
#  'duphaston',
#  'vargatef',
#  'isopto atropine ophth soln',
#  'eucerin dermo purifier cleanser',
#  'astaz-p infusion',
#  'brintellix',
#  'addamel-n',
#  'azacitidine(azadine)',
#  'oestrogel topical gel',
#  'sandimmun',
#  'ibuprofen(heidi)',
#  'dipazide',
#  'vagifem controlled-release vag',
#  'berodual mdi',
#  'glypressin infusion',
#  'macmiror',
#  'dobutamine',
#  'ultibro',
#  'ceftazidime/avibactam(zavicefta)',
#  'certican',
#  'survanta intratracheal susp',
#  'stelara',
#  'marvelon',
#  'ribomustin',
#  'diamine penicillin',
#  'vectibix',
#  'shohl solution',
#  'toujeo',
#  'tetracaine',
#  'spiriva respimat',
#  'pas sodium enteric-coated',
#  'jardiance',
#  'edurant',
#  'aluminium hydroxide gpo',
#  'exocin ophth soln',
#  'bunase aqueous nasal spray',
#  'duovisc',
#  'combigan eye drops',
#  'exjade',
#  'trastuzumab(ogivri)',
#  'clofazimine',
#  'gliclazide(glycon)',
#  'cef-3 im/iv powd for',
#  'nolvadex-d',
#  'urogutt',
#  'cilast baume b5',
#  'mupirocin(bactafect) ointment',
#  'nevirapine mylan',
#  'duratocin',
#  'cordarone',
#  'calvin plus',
#  'norxacin film-coated',
#  'madopar hbs cr',
#  'zovirax ophthalmic ointment ophth oint',
#  'firmagon',
#  'b-coze',
#  'fentanyl',
#  'ฟ้าทะลายโจรชนิดผงบด(pimpa)',
#  'vitamin k',
#  'glucophage film-coated',
#  'chlorpheniramine',
#  'elonza',
#  'diphtheria antitoxin',
#  'deeptyl',
#  'eucerin sun spf60',
#  'ritonavir(rinavir)',
#  'inhalex forte nebulising solution',
#  'alpha d3 soft-gelatin',
#  'epokine',
#  'vabon',
#  'doxetaxel',
#  'cosopt eye drops',
#  'tranmed',
#  'hibiscrub scrub',
#  'spornar',
#  'salazopyrin en enteric-coated',
#  'eucerin sun dry touch',
#  'ebixa',
#  'campto infusion',
#  'rituximab(rixathon)',
#  'placis',
#  'quetiapine(quantia)',
#  'sianem(imipenem/cilastatin)',
#  'budecort cfc-free mdi',
#  'kivexa(600/300) ฺ',
#  'acupan',
#  'ketosteril film-coated',
#  'metronidazole(fk)',
#  'obimin-az',
#  'bortezomib(myborte)',
#  'chlorhexidine',
#  'pristiq xr',
#  'holoxan infusion',
#  'น้ำยาล้างมือ waterless',
#  'water for irrigation',
#  'hydroxychloroquine(quinnel)',
#  'avexa',
#  'unitoral  (เฉพาะ colon,rectum)',
#  'primacor infusion',
#  'cettec syr',
#  'risperdal quicklet orodispersible',
#  'zafatek',
#  'aimovig',
#  'augmentin',
#  'mestinon drag',
#  'lucentis',
#  'mitomycin-c',
#  'sprycel',
#  'vigadexa ophth soln',
#  'primaquine gpo',
#  'androgel topical gel',
#  'lorviqua',
#  'dorner fc',
#  'furosemide',
#  'invega sustenna pre-filled',
#  'pletaal',
#  'amoxycillin',
#  'fluimucil',
#  'healon gv ophth soln',
#  'triamcinolone(gpo)',
#  'actilyse',
#  'physiogel soothing care a.i. cream',
#  'betamethasone gpo cream',
#  'epiduo topical gel',
#  'terbutaline sulfate gpo',
#  'remdesivir(cipremi)',
#  'fycompa',
#  'infloran',
#  'coal tar shampoo',
#  'adrim',
#  'beconase aqueous nasal spray',
#  'zaditen',
#  'remeron sol',
#  'dilizem',
#  'hialid',
#  'ritonavir',
#  'ursolin',
#  'natural vitamin e (mega)',
#  'duodart',
#  'xalacom eye drops',
#  'madopar dispersible',
#  'steritalc',
#  'bonviva film-coated',
#  'androlic',
#  'restasis ophth emulsion',
#  'neomycin',
#  'invega trinza',
#  'piozone',
#  'sertraline(sisalon)',
#  'evusheld',
#  'priorix vaccine',
#  'gardasil vaccine',
#  'sudo',
#  'pentacarinat',
#  'clarith film-coated',
#  'lubric eyes eye drop',
#  'actrapid',
#  'avamigran film-coated',
#  'brilinta',
#  'fluorescite',
#  'stalevo',
#  'clindamycin(rosil)',
#  'potassium chloride',
#  'tapcom eye drop',
#  'hydrea',
#  'diamicron',
#  'imuran',
#  'vaxigrip vaccine',
#  'colistin (mellistin)',
#  'trazodel',
#  'zestril',
#  'seroquel',
#  'sildenafil(silatio)',
#  'cetaphil body moisturizer',
#  'oskept',
#  'reparil dragee',
#  'infanolyte solution',
#  'chalk',
#  'zymar ophth soln',
#  'endura eye drops',
#  'pilocarpine',
#  'ninlaro',
#  'tambocor',
#  'halaven',
#  'xylocaine topical topical spray',
#  'cefuroxime(furoxime)',
#  'furosemide gpo',
#  'vilerm',
#  'sifrol',
#  'valtrex film-coated',
#  'kivexa(600/300) ฺ (ปส)',
#  'betaloc',
#  'vitamin b1 anb',
#  'tenofovir',
#  'ethambutol gpo',
#  'mozobil',
#  'eucerin soothing lotion',
#  'amoxicillin+clavulanic(cavumox)',
#  'marcaine spinal',
#  'potassium chloride mixture',
#  'influenza vaccine(บุคลากร)',
#  'mycamine powd for',
#  'b.s.s plastic bag',
#  'ofev',
#  'hydroxyzine',
#  'lantus solostar pre-filled pen',
#  'lamictal film-coated',
#  'zyrtec oral soln',
#  'dianeal twinbag pd2',
#  'dexilant',
#  'rabeprazole(sandoz)',
#  'donepezil(stada)',
#  'phosphate mixture',
#  'progynova',
#  'gammaraas',
#  'cybele scagel',
#  'arteoptic eye soln',
#  'praluent',
#  'hepatitis vaccine(บุคคลากร)',
#  'methycobal',
#  'prostigmin',
#  'mycostatin oral suspension',
#  'sebivo film-coated',
#  'niflec powd for oral liqd',
#  'linezolid',
#  'dacogen',
#  'pyrimethamine',
#  'prothionamide',
#  'eciine(intae)',
#  'onglyza film-coated',
#  'aspirin(aspent m)',
#  'castellani paint topical soln',
#  'optive fusion eye drop',
#  'giotrif',
#  'hartsorb sublingual',
#  'sofosbuvir+velpatasvir(gpo-hep c)',
#  'circadin pr',
#  'sandimmun neoral',
#  'vitamin e',
#  'streptomycin',
#  'tenofovir/emtriciine(teno-em)',
#  'xamiol topical gel',
#  'paxlovid',
#  'urea in',
#  'livalo film-coated',
#  'xylocaine',
#  'heparin',
#  'creon',
#  'clarithromycin(klarithro rx)',
#  'erleada',
#  'mucosta',
#  'tetagam-p',
#  'zolotem',
#  'antacil',
#  'hbig(immunohbs)',
#  'vermectin',
#  'dexamethasone(lodexa)',
#  'spiolto respimat',
#  'wellbutrin xl xr-fc',
#  'aredia infusion',
#  'vytorin',
#  'ribavirin(gpo)',
#  'budenofalk',
#  'terramycin ophth oint',
#  'felodipine sandoz sr',
#  'invokana',
#  'acetic acid',
#  'nuelin sr sr',
#  'norflex sr',
#  'pernazine',
#  'ulcefate oral susp',
#  'ostex',
#  'calamine lotion',
#  'aromasin sugar-coated',
#  'neo penotran forte vaginal suppo.',
#  'loperamide(patardium)',
#  'bactroban oint',
#  'glyxambi',
#  'avaxim',
#  'meiact',
#  'rituximab(truxima)',
#  'pergoveris',
#  'ial-f',
#  'hyoscine(myspa)',
#  'mertigo',
#  'nebido',
#  'cortrosyn',
#  'mybacin loz',
#  'iliadin nasal drops',
#  'tritace',
#  'yervoy',
#  'acyclovir(paviria)',
#  'tropicamide',
#  'testosterone enanthate(rotexmedica)',
#  'bicnu',
#  'benzhexol gpo',
#  'kanolone -f',
#  'metaplex',
#  'dmso',
#  'estrogen',
#  'clotrimazole',
#  'pomalyst',
#  'duphalac syr',
#  'visudyne',
#  'nitroject',
#  'erlotinib(teva)',
#  'afinitor',
#  'orgalutran pre-filled',
#  'sifrol er',
#  'mixtard',
#  'valcyte film-coated',
#  'antacil hh',
#  'peditrace',
#  'myfortic gastro-resistant',
#  'kadcyla',
#  'colofac',
#  'bioferon',
#  'flixonase aqueous nasal spray',
#  ...}

# %%
clean = pd.DataFrame(cleaned_drugdigits).shape
clean
# Out:
# (11907, 1)

# %%
# สร้าง DataFrame จากลิสต์ drugCol3 และ cleaned_drugdigits
df_drug = pd.DataFrame({'DrugName': drugCol3 + cleaned_drugdigits})
df_generic = pd.DataFrame({'GenericName': genericCol3})

# รวม DataFrame df_drug และ df_generic เพื่อสร้าง DataFrame df_combined
df_combined = pd.concat([df_drug, df_generic], axis=1)

# เพิ่มคอลัมน์ 'DrugName' ให้ยาวเท่ากับคอลัมน์ 'GenericName' โดยเติมค่า NaN ในคอลัมน์ที่ข้อมูลมากกว่าหรือน้อยกว่ากัน
df_combined['DrugName'] = df_combined['DrugName'].combine_first(df_combined['GenericName'])

# Count unique values for 'DrugName'
drug_value_counts = df_combined['DrugName'].value_counts()

# Count unique values for 'GenericName'
generic_value_counts = df_combined['GenericName'].value_counts()

# %%
pre_drug = df_combined['DrugName'].value_counts().reset_index()
pre_drug.columns = ['DrugName', 'Count']

pre_generic = df_combined['GenericName'].value_counts().reset_index()
pre_generic.columns = ['GenericName', 'Count']

pre_count = df_combined.groupby(['DrugName', 'GenericName']).size().reset_index()
pre_count.columns = ['DrugName', 'GenericName', 'Count']

# %%
pre_df = pd.DataFrame(pre_count)
pre_df
# Out:
#                                                DrugName  \
# 0
# 1
# 2                       2% chlorhexidine in 70% alcohol
# 3                           5-fu /. for subconjunctival
# 4                                                 a m k
# ...                                                 ...
# 4644  ไหมเย็บเนื้อเยื่อเข้ากับสมอยึดตรีงกระดูกultrab...
# 4645  ไหมเย็บแผล ชนิดเส้นเดี่ยว ไม่ละลายน้ำ ผลิตจากพ...
# 4646  ไหมเย็บแผล ชนิดเส้นเดี่ยว ไม่ละลายน้ำ ผลิตจากโ...
# 4647  ไหมเย็บแผล ชนิดเส้นเดี่ยว ไม่ละลายน้ำ ผลิตจากโ...
# 4648                           ไฮโดรเจลผสมซิลเวอร์ ขนาด
#
#                           GenericName  Count
# 0                             3tc 150    800
# 1                             lamivir    289
# 2     2% chlorhexidine in 70% alcohol     47
# 3      5-fu 10/ . for subconjunctival     19
# 4                                 amk  24303
# ...                               ...    ...
# 4644                              nan      1
# 4645                              nan      1
# 4646                              nan      1
# 4647                              nan      1
# 4648                              nan      9
#
# [4649 rows x 3 columns]

# %% [markdown]
# ##🗂️Import data: visit

# %%
visit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-e62d5ef64bcf> in <cell line: 1>()
# ----> 1 visit
#
# NameError: name 'visit' is not defined

# %% [markdown]
# ### **🔎UniqueValues**
# columns: **PatientUID, PatientvisitUID, Sex, Age, ENTY, NATNL** in Visit.csv

# %%
visit_Age = visit['Age'].value_counts().reset_index()
visit_Age.columns = ['UniqueValue','Count']

visit_ENTY = visit['ENTY'].value_counts().reset_index()
visit_ENTY.columns = ['UniqueValue','Count']

visit_NATNL = visit['NATNL'].value_counts().reset_index()
visit_NATNL.columns = ['UniqueValue','Count']

# Specify the columns for unique value counting
columns_to_count = ['PatientUID', 'PatientvisitUID', 'Sex', 'Age', 'ENTY', 'NATNL']

# Count unique values in the specified columns
visit_count = visit[columns_to_count].value_counts().reset_index()
visit_count.columns = ['PatientUID', 'PatientvisitUID', 'Sex', 'Age', 'ENTY', 'NATNL', 'Count']

columns_to_count = ['PatientUID', 'Sex', 'Age', 'ENTY', 'NATNL']

# Count unique values in the specified columns
visit_grouped = visit.groupby('PatientUID')[columns_to_count].nunique()

# Rename the columns
new_columns = ['Count_' + column for column in columns_to_count]
visit_grouped.columns = new_columns

# Merge with the existing visit_count DataFrame
visit_count = visit_count.merge(visit_grouped, on='PatientUID', how='left')

# Select the required columns
required_columns = ['PatientvisitUID', 'Sex', 'Age', 'ENTY', 'NATNL', 'Count_Sex', 'Count_Age', 'Count_ENTY', 'Count_NATNL']
visit_count = visit_count.reindex(required_columns, axis=1)


visit_df = pd.DataFrame(visit_grouped)
visit_df

# %%
import pandas as pd

# กำหนดคอลัมน์ที่ต้องการนับค่าที่ไม่ซ้ำกัน
columns_to_count = ['PatientvisitUID', 'Sex', 'Age', 'ENTY', 'NATNL']

# จัดกลุ่มและนับค่าที่ไม่ซ้ำกันตามดัชนี "PatientUID"
visit_grouped = visit.groupby('PatientUID')[columns_to_count].nunique()

# เปลี่ยนชื่อคอลัมน์ใหม่
visit_grouped.columns = ['Count_' + column for column in columns_to_count]

# %%
# ตรวจสอบว่ามีค่าดัชนีซ้ำกันทั้งหมดหรือไม่
is_any_duplicated = visit_grouped.index.duplicated().any()
is_any_duplicated

# %%
visit_df = pd.DataFrame(visit_grouped)
visit_df

# %% [markdown]
# ## **Excel**

# %%
with pd.ExcelWriter('CountUniqueValues.xlsx') as writer:
    vitalsign_df.to_excel(writer, sheet_name='Vitalsign')
    diag_df.to_excel(writer, sheet_name='Diagnosis')
    lab_df.to_excel(writer, sheet_name='Lab')
    pre_df.to_excel(writer, sheet_name='Prescription')
    visit_df.to_excel(writer, sheet_name='Visit', index=False)

# %%
with pd.ExcelWriter('Prescription.xlsx') as writer:
    pre_df.to_excel(writer, sheet_name='Prescription')
